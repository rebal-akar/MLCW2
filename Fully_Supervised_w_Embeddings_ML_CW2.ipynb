# %% [markdown]
# <a href="https://colab.research.google.com/github/rebal-akar/MLCW2/blob/main/Fully_Supervised_w_Embeddings_ML_CW2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Self-supervised

# %% [markdown]
# Imports

# %%
# ⚙️ Core Python & OS
import os
import math
import random

# 📦 PyTorch
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
import torchvision.transforms as transforms
import torchvision.datasets as datasets
import torchvision.models as models

# 📊 Data Science
import numpy as np
import pandas as pd
from tqdm import tqdm

# 📈 Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# 🤖 ML Tools
from sklearn.cluster import KMeans, MiniBatchKMeans
from sklearn.neighbors import NearestNeighbors
from sklearn.manifold import TSNE

# %% [markdown]
# Cell 2: Load Pre-trained SimCLR Model

# %%
class SimCLRModel(nn.Module):
    def __init__(self):
        super(SimCLRModel, self).__init__()
        resnet = models.resnet18(pretrained=False)
        resnet.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        resnet.maxpool = nn.Identity()
        resnet.fc = nn.Identity()
        self.encoder = resnet
        self.projector = nn.Sequential(
            nn.Linear(512, 512),
            nn.ReLU(),
            nn.Linear(512, 128)
        )

    def forward(self, x, return_embedding=False):
        h = self.encoder(x)
        h = torch.flatten(h, 1)
        if return_embedding:
            return h
        return self.projector(h)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = SimCLRModel().to(device)

model_path = "/content/drive/MyDrive/Typiclust/simclr_cifar-10.pth"
checkpoint = torch.load(model_path, map_location=device)

from collections import OrderedDict
new_state_dict = OrderedDict()
for key, value in checkpoint.items():
    if key.startswith("backbone."):
        new_key = "encoder." + key[len("backbone."):]
    elif key.startswith("contrastive_head."):
        new_key = "projector." + key[len("contrastive_head."):]
    else:
        new_key = key
    if "shortcut" in new_key:
        new_key = new_key.replace("shortcut", "downsample")
    new_state_dict[new_key] = value

missing_keys, unexpected_keys = model.load_state_dict(new_state_dict, strict=False)
print("Missing keys:", missing_keys)
print("Unexpected keys:", unexpected_keys)
model.eval()
print("✅ Pretrained SimCLR model loaded successfully!")
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# Missing keys: []
# Unexpected keys: []
# ✅ Pretrained SimCLR model loaded successfully!

# %% [markdown]
# Cell 3: Data Preparation – Load CIFAR-10 Dataset

# %%
# Define transforms; ensure normalization matches SimCLR training

train_transform = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465),
                         (0.2023, 0.1994, 0.2010)),
])
test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465),
                         (0.2023, 0.1994, 0.2010)),
])
train_dataset = datasets.CIFAR10(root='./data', train=True, download=True, transform=train_transform)
test_dataset  = datasets.CIFAR10(root='./data', train=False, download=True, transform=test_transform)

batch_size = 128
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False, num_workers=2)
test_loader  = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=2)

print("CIFAR-10 data loaded.")
# Out:
# 100%|██████████| 170M/170M [00:11<00:00, 15.5MB/s]
# CIFAR-10 data loaded.

# %% [markdown]
# Cell 4: Extract Embeddings Using the Pre-trained Model

# %%
embeddings_path = "embeddings.npy"
indices_path = "indices.npy"

def extract_embeddings(model, loader):
    model.eval()
    all_embeddings = []
    all_indices = []
    with torch.no_grad():
        for i, (images, _) in enumerate(tqdm(loader, desc="Extracting embeddings")):
            images = images.to(device)
            feats = model(images, return_embedding=True)
            feats = feats.cpu().numpy()
            # L2-normalize the extracted features
            norms = np.linalg.norm(feats, axis=1, keepdims=True) + 1e-8
            feats = feats / norms
            all_embeddings.append(feats)
            start_idx = i * batch_size
            end_idx = start_idx + images.size(0)
            all_indices.extend(range(start_idx, end_idx))
    embeddings = np.concatenate(all_embeddings, axis=0)
    return embeddings, all_indices

embeddings, indices = extract_embeddings(model, train_loader)
np.save(embeddings_path, embeddings)
np.save(indices_path, indices)
print("Feature extraction complete. Embeddings shape:", embeddings.shape)
# Out:
# Extracting embeddings: 100%|██████████| 391/391 [00:13<00:00, 28.93it/s]
# Feature extraction complete. Embeddings shape: (50000, 512)

# %% [markdown]
# Cell 5: Clustering and Computing Typicality

# %%
def compute_typicality_nn(cluster_features, K=20):
    """
    Compute typicality as the inverse of the average Euclidean distance
    to the min{20, cluster_size} nearest neighbors (excluding the point itself).
    """
    n = cluster_features.shape[0]
    if n == 0:
        return np.array([])
    nbrs = NearestNeighbors(n_neighbors=min(K+1, n), algorithm='auto',metric='euclidean').fit(cluster_features)
    distances, _ = nbrs.kneighbors(cluster_features)
    avg_distances = np.mean(distances[:, 1:], axis=1)
    typicality = 1.0 / (avg_distances + 1e-8)
    return typicality

def typiclust_pool_selection_batch(unlabeled_embeddings, unlabeled_ids, budget, max_clusters, labeled_embeddings, labeled_ids):
    """
    Batch-select query samples from the unlabeled pool based on clustering and typicality,
    following the TP CRP variant in the paper.

    The algorithm partitions the combined (unlabeled + labeled) embeddings into
    K = min(|L| + B, max_clusters) clusters. It then identifies uncovered clusters
    (clusters with 0 labeled points and with at least 5 samples) and from the
    B largest uncovered clusters selects the most typical sample (i.e. the one with the highest
    typicality score computed as the inverse of the average distance to min{20, cluster_size} nearest neighbors).

    Args:
      unlabeled_embeddings: np.array of embeddings for the current unlabeled pool.
      unlabeled_ids: list of indices corresponding to these embeddings.
      budget: number of new samples to query in this iteration.
      max_clusters: maximum allowed clusters.
      labeled_embeddings: np.array of embeddings for the currently labeled samples.
      labeled_ids: list of indices corresponding to the labeled samples.

    Returns:
      queries: list of selected indices (from unlabeled_ids).
    """
    # Determine number of clusters: K = min(|L| + budget, max_clusters)
    current_labeled_count = len(labeled_ids)
    n_clusters = min(current_labeled_count + budget, max_clusters)

    if current_labeled_count > 0:
        X_total = np.concatenate([unlabeled_embeddings, labeled_embeddings], axis=0)
        is_unlabeled = np.array([True] * unlabeled_embeddings.shape[0] + [False] * labeled_embeddings.shape[0])
    else:
        X_total = unlabeled_embeddings
        is_unlabeled = np.array([True] * unlabeled_embeddings.shape[0])

    # Choose clustering algorithm based on n_clusters.
    if n_clusters > 50:
        clusterer = MiniBatchKMeans(n_clusters=n_clusters, random_state=None)
    else:
        clusterer = KMeans(n_clusters=n_clusters, random_state=None)
    labels = clusterer.fit_predict(X_total)

    # Build cluster statistics in a list
    cluster_stats = []
    for cluster in np.unique(labels):
        idxs = np.where(labels == cluster)[0]
        cluster_size = len(idxs)
        labeled_count = np.sum(~is_unlabeled[idxs])
        unlabeled_idxs = [i for i in idxs if is_unlabeled[i]]
        # Only include clusters that have at least min_cluster_size unlabeled points
        if len(unlabeled_idxs) >= 5:
            cluster_stats.append({
                'cluster_id': cluster,
                'cluster_size': cluster_size,
                'labeled_count': labeled_count,
                'unlabeled_idx': unlabeled_idxs
            })

    if len(cluster_stats) == 0:
        return []
    clusters_df = pd.DataFrame(cluster_stats)

    # Sort clusters: first by labeled_count (ascending), then by cluster_size (descending)
    clusters_df = clusters_df.sort_values(by=['labeled_count', 'cluster_size'], ascending=[True, False])
    sorted_cluster_ids = clusters_df['cluster_id'].tolist()



    # Iterative selection loop: select one sample per iteration, cycling through sorted clusters if needed.
    queries = []
    for i in range(budget):
        cluster_id = sorted_cluster_ids[i % len(sorted_cluster_ids)]
        row = clusters_df[clusters_df['cluster_id'] == cluster_id].iloc[0]
        candidate_indices = row['unlabeled_idx']
        if len(candidate_indices) == 0:
            continue
        # Extract candidate embeddings from the unlabeled pool
        candidate_embeddings = unlabeled_embeddings[candidate_indices]
        knn = min(20, candidate_embeddings.shape[0])
        typ_scores = compute_typicality_nn(candidate_embeddings, K=knn)
        # Select the candidate with the highest typicality
        best_local_idx = candidate_indices[np.argmax(typ_scores)]
        queries.append(unlabeled_ids[best_local_idx])
        # Mark this candidate as selected: remove it from the candidate list in clusters_df
        updated_candidates = [idx for idx in candidate_indices if idx != best_local_idx]
        clusters_df.loc[clusters_df['cluster_id'] == cluster_id, 'unlabeled_idx'] = pd.Series([updated_candidates], index=clusters_df.loc[clusters_df['cluster_id'] == cluster_id].index)
    return queries

# %% [markdown]
# Cell 5: Define Linear Classifier Training with Learning Rate Scheduler

# %%
class LinearClassifier(nn.Module):
    def __init__(self, input_dim=512, num_classes=10):
        super(LinearClassifier, self).__init__()
        self.fc = nn.Linear(input_dim, num_classes)

    def forward(self, x):
        return self.fc(x)

def train_linear_classifier(train_emb, train_lbl, test_emb, test_lbl, num_epochs=200, lr=0.025):
    classifier = LinearClassifier(input_dim=train_emb.shape[1], num_classes=10).to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(classifier.parameters(), lr=lr, momentum=0.9)
    scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=num_epochs)

    train_emb = torch.tensor(train_emb, dtype=torch.float32).to(device)
    train_lbl = torch.tensor(train_lbl, dtype=torch.long).to(device)
    test_emb = torch.tensor(test_emb, dtype=torch.float32).to(device)
    test_lbl = torch.tensor(test_lbl, dtype=torch.long).to(device)

    for epoch in range(num_epochs):
        classifier.train()
        optimizer.zero_grad()
        outputs = classifier(train_emb)
        loss = criterion(outputs, train_lbl)
        loss.backward()
        optimizer.step()
        scheduler.step()

        if (epoch+1) % 10 == 0:
            classifier.eval()
            with torch.no_grad():
                test_outputs = classifier(test_emb)
                _, predicted = torch.max(test_outputs, 1)
                accuracy = (predicted == test_lbl).float().mean().item()
            print(f"Epoch {epoch+1}/{num_epochs}: Loss = {loss.item():.4f}, Test Accuracy = {accuracy*100:.2f}%")

    return classifier

def evaluate_classifier(classifier, test_emb, test_lbl):
    classifier.eval()
    test_emb = torch.tensor(test_emb, dtype=torch.float32).to(device)
    test_lbl = torch.tensor(test_lbl, dtype=torch.long).to(device)
    with torch.no_grad():
        outputs = classifier(test_emb)
        _, predicted = torch.max(outputs, 1)
        accuracy = (predicted == test_lbl).float().mean().item()
    return accuracy

# %% [markdown]
# Cell 6: Extract Test Embeddings

# %%
def extract_test_embeddings(model, loader):
    model.eval()
    all_test_embeddings = []
    all_test_labels = []
    with torch.no_grad():
        for images, labels in loader:
            images = images.to(device)
            feats = model(images, return_embedding=True)
            feats = feats.cpu().numpy()
            # L2-normalize test embeddings
            norm = np.linalg.norm(feats, axis=1, keepdims=True) + 1e-8
            feats = feats / norm
            all_test_embeddings.append(feats)
            all_test_labels.extend(labels.numpy())
    return np.concatenate(all_test_embeddings, axis=0), np.array(all_test_labels)

test_embeddings, test_labels = extract_test_embeddings(model, test_loader)
print("Test embeddings extracted. Shape:", test_embeddings.shape)
# Out:
# Test embeddings extracted. Shape: (10000, 512)

# %% [markdown]
# Cell 7: Iterative Active Learning Loop with TypiClust Selection

# %%
budget_per_iter = 10
num_iterations = 6
max_clusters = 500
def run_active_learning(selection_func, budget_per_iter, num_iterations, max_clusters):
    """
    Runs an active learning loop using a given selection function.

    Args:
      selection_func: function to select new query indices (e.g., typiclust_pool_selection_batch or random_selection).
      budget_per_iter: number of new samples to query each iteration.
      num_iterations: total number of active learning iterations.
      max_clusters: maximum number of clusters used in selection.

    Returns:
      cumulative_budget: list of cumulative labeled sample counts per iteration.
      performance_history: list of test accuracies per iteration.
    """
    labeled_indices = []
    unlabeled_indices = indices.copy()
    performance_history = []
    cumulative_budget = []

    train_labels = np.array(train_dataset.targets)

    for iteration in range(num_iterations):
        print(f"\nActive Learning Iteration {iteration+1}/{num_iterations}")
        print(f"Current labeled samples: {len(labeled_indices)}")
        print(f"Current unlabeled samples: {len(unlabeled_indices)}")

        current_unlabeled_mask = np.isin(indices, unlabeled_indices)
        unlabeled_embeddings = embeddings[current_unlabeled_mask]
        unlabeled_ids = np.array(indices)[current_unlabeled_mask].tolist()
        print(f"Unlabeled embeddings shape: {unlabeled_embeddings.shape}")

        if len(labeled_indices) > 0:
            current_labeled_mask = np.isin(indices, labeled_indices)
            labeled_embeddings_current = embeddings[current_labeled_mask]
        else:
            labeled_embeddings_current = np.empty((0, embeddings.shape[1]))

        # Use the provided selection function to select a batch of new indices.
        selected_pool = selection_func(
            unlabeled_embeddings, unlabeled_ids, budget_per_iter, max_clusters,
            labeled_embeddings_current, labeled_indices
        )
        print("Selected indices in this iteration:", selected_pool)

        # Update the labeled and unlabeled pools.
        # Remove any duplicate or already-labeled indices from the selection
        selected_pool = list(set(selected_pool) - set(labeled_indices))
        selected_pool = [idx for idx in selected_pool if idx in unlabeled_indices]
        intersection = set(selected_pool) & set(labeled_indices)
        assert len(intersection) == 0, f"Selected indices already labeled! Overlap: {intersection}"
        selected_pool = list(set(selected_pool) - set(labeled_indices))
        selected_pool = [idx for idx in selected_pool if idx in unlabeled_indices]
        labeled_indices.extend(selected_pool)
        unlabeled_indices = list(set(unlabeled_indices) - set(selected_pool))

        print(f"Total labeled samples after iteration {iteration+1}: {len(labeled_indices)}")

        # Prepare training data: embeddings and labels for the current labeled set.
        current_train_mask = np.isin(indices, labeled_indices)
        current_train_embeddings = embeddings[current_train_mask]
        current_train_labels = train_labels[current_train_mask]

        classifier = train_linear_classifier(
            current_train_embeddings, current_train_labels,
            test_embeddings, test_labels,
            num_epochs=200, lr=2.5
        )
        # Evaluate test accuracy
        test_acc = evaluate_classifier(classifier, test_embeddings, test_labels)
        performance_history.append(test_acc)
        cumulative_budget.append(len(labeled_indices))
        print(f"Iteration {iteration+1}: Cumulative Budget = {len(labeled_indices)}, Test Accuracy = {test_acc*100:.2f}%")

    return cumulative_budget, performance_history


def typiclust_selection(unlabeled_embeddings, unlabeled_ids, budget, max_clusters, labeled_embeddings, labeled_ids):
    """
    Use the TypiClust (TP CRP) batch selection method.
    """
    return typiclust_pool_selection_batch(
        unlabeled_embeddings, unlabeled_ids, budget, max_clusters,
        labeled_embeddings, labeled_ids
    )

def random_selection(unlabeled_embeddings, unlabeled_ids, budget, max_clusters, labeled_embeddings, labeled_ids):
    """
    Randomly select 'budget' samples from the current unlabeled pool.
    """
    return random.sample(unlabeled_ids, budget)
# Out:
# Active Learning Iteration 1/6
# Current labeled samples: 0
# Current unlabeled samples: 50000
# Unlabeled embeddings shape: (50000, 512)
# Selected indices in this iteration: [8133, 37976, 42315, 9178, 18498, 30570, 20384, 32109, 29916, 34580]
# Total labeled samples after iteration 1: 10
# Epoch 10/200: Loss = 0.0572, Test Accuracy = 56.01%
# Epoch 20/200: Loss = 0.0017, Test Accuracy = 57.07%
# Epoch 30/200: Loss = 0.0005, Test Accuracy = 57.56%
# Epoch 40/200: Loss = 0.0003, Test Accuracy = 57.74%
# Epoch 50/200: Loss = 0.0003, Test Accuracy = 57.79%
# Epoch 60/200: Loss = 0.0002, Test Accuracy = 57.82%
# Epoch 70/200: Loss = 0.0002, Test Accuracy = 57.84%
# Epoch 80/200: Loss = 0.0002, Test Accuracy = 57.88%
# Epoch 90/200: Loss = 0.0002, Test Accuracy = 57.88%
# Epoch 100/200: Loss = 0.0002, Test Accuracy = 57.87%
# Epoch 110/200: Loss = 0.0002, Test Accuracy = 57.89%
# Epoch 120/200: Loss = 0.0002, Test Accuracy = 57.89%
# Epoch 130/200: Loss = 0.0002, Test Accuracy = 57.87%
# Epoch 140/200: Loss = 0.0002, Test Accuracy = 57.88%
# Epoch 150/200: Loss = 0.0002, Test Accuracy = 57.89%
# Epoch 160/200: Loss = 0.0002, Test Accuracy = 57.89%
# Epoch 170/200: Loss = 0.0002, Test Accuracy = 57.89%
# Epoch 180/200: Loss = 0.0002, Test Accuracy = 57.89%
# Epoch 190/200: Loss = 0.0002, Test Accuracy = 57.89%
# Epoch 200/200: Loss = 0.0002, Test Accuracy = 57.89%
# Iteration 1: Cumulative Budget = 10, Test Accuracy = 57.89%
#
# Active Learning Iteration 2/6
# Current labeled samples: 10
# Current unlabeled samples: 49990
# Unlabeled embeddings shape: (49990, 512)
# Selected indices in this iteration: [23981, 16868, 30141, 46787, 23817, 42528, 37583, 1681, 2814, 9408]
# Total labeled samples after iteration 2: 20
# Epoch 10/200: Loss = 0.2892, Test Accuracy = 55.24%
# Epoch 20/200: Loss = 0.0164, Test Accuracy = 64.97%
# Epoch 30/200: Loss = 0.0051, Test Accuracy = 63.88%
# Epoch 40/200: Loss = 0.0031, Test Accuracy = 63.30%
# Epoch 50/200: Loss = 0.0025, Test Accuracy = 62.99%
# Epoch 60/200: Loss = 0.0023, Test Accuracy = 62.82%
# Epoch 70/200: Loss = 0.0022, Test Accuracy = 62.78%
# Epoch 80/200: Loss = 0.0021, Test Accuracy = 62.79%
# Epoch 90/200: Loss = 0.0020, Test Accuracy = 62.80%
# Epoch 100/200: Loss = 0.0020, Test Accuracy = 62.72%
# Epoch 110/200: Loss = 0.0019, Test Accuracy = 62.70%
# Epoch 120/200: Loss = 0.0019, Test Accuracy = 62.67%
# Epoch 130/200: Loss = 0.0019, Test Accuracy = 62.60%
# Epoch 140/200: Loss = 0.0019, Test Accuracy = 62.58%
# Epoch 150/200: Loss = 0.0019, Test Accuracy = 62.57%
# Epoch 160/200: Loss = 0.0019, Test Accuracy = 62.54%
# Epoch 170/200: Loss = 0.0019, Test Accuracy = 62.52%
# Epoch 180/200: Loss = 0.0019, Test Accuracy = 62.49%
# Epoch 190/200: Loss = 0.0019, Test Accuracy = 62.50%
# Epoch 200/200: Loss = 0.0019, Test Accuracy = 62.50%
# Iteration 2: Cumulative Budget = 20, Test Accuracy = 62.50%
#
# Active Learning Iteration 3/6
# Current labeled samples: 20
# Current unlabeled samples: 49980
# Unlabeled embeddings shape: (49980, 512)
# Selected indices in this iteration: [36070, 28657, 10031, 26289, 23097, 2640, 2145, 28692, 42707, 30269]
# Total labeled samples after iteration 3: 30
# Epoch 10/200: Loss = 0.5134, Test Accuracy = 72.78%
# Epoch 20/200: Loss = 0.0376, Test Accuracy = 74.23%
# Epoch 30/200: Loss = 0.0113, Test Accuracy = 73.59%
# Epoch 40/200: Loss = 0.0071, Test Accuracy = 73.56%
# Epoch 50/200: Loss = 0.0058, Test Accuracy = 73.86%
# Epoch 60/200: Loss = 0.0053, Test Accuracy = 73.86%
# Epoch 70/200: Loss = 0.0050, Test Accuracy = 73.96%
# Epoch 80/200: Loss = 0.0048, Test Accuracy = 74.15%
# Epoch 90/200: Loss = 0.0047, Test Accuracy = 74.17%
# Epoch 100/200: Loss = 0.0046, Test Accuracy = 74.21%
# Epoch 110/200: Loss = 0.0045, Test Accuracy = 74.24%
# Epoch 120/200: Loss = 0.0044, Test Accuracy = 74.26%
# Epoch 130/200: Loss = 0.0044, Test Accuracy = 74.28%
# Epoch 140/200: Loss = 0.0043, Test Accuracy = 74.28%
# Epoch 150/200: Loss = 0.0043, Test Accuracy = 74.28%
# Epoch 160/200: Loss = 0.0043, Test Accuracy = 74.29%
# Epoch 170/200: Loss = 0.0043, Test Accuracy = 74.30%
# Epoch 180/200: Loss = 0.0043, Test Accuracy = 74.30%
# Epoch 190/200: Loss = 0.0042, Test Accuracy = 74.30%
# Epoch 200/200: Loss = 0.0042, Test Accuracy = 74.30%
# Iteration 3: Cumulative Budget = 30, Test Accuracy = 74.30%
#
# Active Learning Iteration 4/6
# Current labeled samples: 30
# Current unlabeled samples: 49970
# Unlabeled embeddings shape: (49970, 512)
# Selected indices in this iteration: [17258, 23208, 1209, 16457, 31677, 1277, 44994, 29808, 37319, 40502]
# Total labeled samples after iteration 4: 40
# Epoch 10/200: Loss = 0.6365, Test Accuracy = 74.54%
# Epoch 20/200: Loss = 0.0609, Test Accuracy = 76.61%
# Epoch 30/200: Loss = 0.0184, Test Accuracy = 76.13%
# Epoch 40/200: Loss = 0.0114, Test Accuracy = 76.13%
# Epoch 50/200: Loss = 0.0092, Test Accuracy = 76.43%
# Epoch 60/200: Loss = 0.0083, Test Accuracy = 76.59%
# Epoch 70/200: Loss = 0.0078, Test Accuracy = 76.69%
# Epoch 80/200: Loss = 0.0074, Test Accuracy = 76.81%
# Epoch 90/200: Loss = 0.0072, Test Accuracy = 76.82%
# Epoch 100/200: Loss = 0.0069, Test Accuracy = 76.81%
# Epoch 110/200: Loss = 0.0068, Test Accuracy = 76.81%
# Epoch 120/200: Loss = 0.0066, Test Accuracy = 76.83%
# Epoch 130/200: Loss = 0.0065, Test Accuracy = 76.83%
# Epoch 140/200: Loss = 0.0065, Test Accuracy = 76.83%
# Epoch 150/200: Loss = 0.0064, Test Accuracy = 76.86%
# Epoch 160/200: Loss = 0.0064, Test Accuracy = 76.86%
# Epoch 170/200: Loss = 0.0063, Test Accuracy = 76.85%
# Epoch 180/200: Loss = 0.0063, Test Accuracy = 76.86%
# Epoch 190/200: Loss = 0.0063, Test Accuracy = 76.86%
# Epoch 200/200: Loss = 0.0063, Test Accuracy = 76.86%
# Iteration 4: Cumulative Budget = 40, Test Accuracy = 76.86%
#
# Active Learning Iteration 5/6
# Current labeled samples: 40
# Current unlabeled samples: 49960
# Unlabeled embeddings shape: (49960, 512)
# Selected indices in this iteration: [38400, 7293, 17548, 33804, 3585, 16688, 30471, 36394, 2348, 44760]
# Total labeled samples after iteration 5: 50
# Epoch 10/200: Loss = 0.7559, Test Accuracy = 79.33%
# Epoch 20/200: Loss = 0.0870, Test Accuracy = 78.93%
# Epoch 30/200: Loss = 0.0269, Test Accuracy = 79.69%
# Epoch 40/200: Loss = 0.0163, Test Accuracy = 79.81%
# Epoch 50/200: Loss = 0.0129, Test Accuracy = 79.69%
# Epoch 60/200: Loss = 0.0115, Test Accuracy = 79.75%
# Epoch 70/200: Loss = 0.0106, Test Accuracy = 79.81%
# Epoch 80/200: Loss = 0.0101, Test Accuracy = 79.80%
# Epoch 90/200: Loss = 0.0097, Test Accuracy = 79.79%
# Epoch 100/200: Loss = 0.0093, Test Accuracy = 79.81%
# Epoch 110/200: Loss = 0.0091, Test Accuracy = 79.81%
# Epoch 120/200: Loss = 0.0089, Test Accuracy = 79.81%
# Epoch 130/200: Loss = 0.0087, Test Accuracy = 79.82%
# Epoch 140/200: Loss = 0.0086, Test Accuracy = 79.83%
# Epoch 150/200: Loss = 0.0085, Test Accuracy = 79.83%
# Epoch 160/200: Loss = 0.0085, Test Accuracy = 79.84%
# Epoch 170/200: Loss = 0.0084, Test Accuracy = 79.84%
# Epoch 180/200: Loss = 0.0084, Test Accuracy = 79.84%
# Epoch 190/200: Loss = 0.0084, Test Accuracy = 79.84%
# Epoch 200/200: Loss = 0.0084, Test Accuracy = 79.84%
# Iteration 5: Cumulative Budget = 50, Test Accuracy = 79.84%
#
# Active Learning Iteration 6/6
# Current labeled samples: 50
# Current unlabeled samples: 49950
# Unlabeled embeddings shape: (49950, 512)
# Selected indices in this iteration: [157, 4527, 27462, 49081, 40763, 23767, 5402, 8596, 10169, 37580]
# Total labeled samples after iteration 6: 60
# Epoch 10/200: Loss = 0.8060, Test Accuracy = 78.41%
# Epoch 20/200: Loss = 0.1113, Test Accuracy = 78.69%
# Epoch 30/200: Loss = 0.0357, Test Accuracy = 79.82%
# Epoch 40/200: Loss = 0.0212, Test Accuracy = 79.83%
# Epoch 50/200: Loss = 0.0166, Test Accuracy = 79.69%
# Epoch 60/200: Loss = 0.0145, Test Accuracy = 79.74%
# Epoch 70/200: Loss = 0.0134, Test Accuracy = 79.79%
# Epoch 80/200: Loss = 0.0126, Test Accuracy = 79.82%
# Epoch 90/200: Loss = 0.0120, Test Accuracy = 79.82%
# Epoch 100/200: Loss = 0.0115, Test Accuracy = 79.82%
# Epoch 110/200: Loss = 0.0112, Test Accuracy = 79.88%
# Epoch 120/200: Loss = 0.0109, Test Accuracy = 79.89%
# Epoch 130/200: Loss = 0.0107, Test Accuracy = 79.91%
# Epoch 140/200: Loss = 0.0105, Test Accuracy = 79.91%
# Epoch 150/200: Loss = 0.0104, Test Accuracy = 79.91%
# Epoch 160/200: Loss = 0.0103, Test Accuracy = 79.91%
# Epoch 170/200: Loss = 0.0103, Test Accuracy = 79.91%
# Epoch 180/200: Loss = 0.0102, Test Accuracy = 79.91%
# Epoch 190/200: Loss = 0.0102, Test Accuracy = 79.91%
# Epoch 200/200: Loss = 0.0102, Test Accuracy = 79.91%
# Iteration 6: Cumulative Budget = 60, Test Accuracy = 79.91%
#
# Active Learning Iteration 1/6
# Current labeled samples: 0
# Current unlabeled samples: 50000
# Unlabeled embeddings shape: (50000, 512)
# Selected indices in this iteration: [27877, 35113, 6706, 38508, 6152, 23213, 22337, 37335, 604, 48820]
# Total labeled samples after iteration 1: 10
# Epoch 10/200: Loss = 0.0406, Test Accuracy = 39.06%
# Epoch 20/200: Loss = 0.0022, Test Accuracy = 37.49%
# Epoch 30/200: Loss = 0.0007, Test Accuracy = 37.17%
# Epoch 40/200: Loss = 0.0005, Test Accuracy = 37.05%
# Epoch 50/200: Loss = 0.0004, Test Accuracy = 36.99%
# Epoch 60/200: Loss = 0.0004, Test Accuracy = 37.05%
# Epoch 70/200: Loss = 0.0003, Test Accuracy = 37.14%
# Epoch 80/200: Loss = 0.0003, Test Accuracy = 37.14%
# Epoch 90/200: Loss = 0.0003, Test Accuracy = 37.13%
# Epoch 100/200: Loss = 0.0003, Test Accuracy = 37.14%
# Epoch 110/200: Loss = 0.0003, Test Accuracy = 37.14%
# Epoch 120/200: Loss = 0.0003, Test Accuracy = 37.17%
# Epoch 130/200: Loss = 0.0003, Test Accuracy = 37.18%
# Epoch 140/200: Loss = 0.0003, Test Accuracy = 37.18%
# Epoch 150/200: Loss = 0.0003, Test Accuracy = 37.20%
# Epoch 160/200: Loss = 0.0003, Test Accuracy = 37.17%
# Epoch 170/200: Loss = 0.0003, Test Accuracy = 37.16%
# Epoch 180/200: Loss = 0.0003, Test Accuracy = 37.16%
# Epoch 190/200: Loss = 0.0003, Test Accuracy = 37.16%
# Epoch 200/200: Loss = 0.0003, Test Accuracy = 37.16%
# Iteration 1: Cumulative Budget = 10, Test Accuracy = 37.16%
#
# Active Learning Iteration 2/6
# Current labeled samples: 10
# Current unlabeled samples: 49990
# Unlabeled embeddings shape: (49990, 512)
# Selected indices in this iteration: [26300, 21864, 7468, 30647, 40084, 23506, 27521, 36300, 43851, 7484]
# Total labeled samples after iteration 2: 20
# Epoch 10/200: Loss = 0.2532, Test Accuracy = 50.70%
# Epoch 20/200: Loss = 0.0157, Test Accuracy = 53.42%
# Epoch 30/200: Loss = 0.0048, Test Accuracy = 52.74%
# Epoch 40/200: Loss = 0.0030, Test Accuracy = 52.82%
# Epoch 50/200: Loss = 0.0024, Test Accuracy = 53.11%
# Epoch 60/200: Loss = 0.0022, Test Accuracy = 53.25%
# Epoch 70/200: Loss = 0.0020, Test Accuracy = 53.20%
# Epoch 80/200: Loss = 0.0020, Test Accuracy = 53.32%
# Epoch 90/200: Loss = 0.0019, Test Accuracy = 53.33%
# Epoch 100/200: Loss = 0.0019, Test Accuracy = 53.33%
# Epoch 110/200: Loss = 0.0018, Test Accuracy = 53.31%
# Epoch 120/200: Loss = 0.0018, Test Accuracy = 53.30%
# Epoch 130/200: Loss = 0.0018, Test Accuracy = 53.29%
# Epoch 140/200: Loss = 0.0018, Test Accuracy = 53.25%
# Epoch 150/200: Loss = 0.0018, Test Accuracy = 53.28%
# Epoch 160/200: Loss = 0.0017, Test Accuracy = 53.28%
# Epoch 170/200: Loss = 0.0017, Test Accuracy = 53.27%
# Epoch 180/200: Loss = 0.0017, Test Accuracy = 53.27%
# Epoch 190/200: Loss = 0.0017, Test Accuracy = 53.27%
# Epoch 200/200: Loss = 0.0017, Test Accuracy = 53.27%
# Iteration 2: Cumulative Budget = 20, Test Accuracy = 53.27%
#
# Active Learning Iteration 3/6
# Current labeled samples: 20
# Current unlabeled samples: 49980
# Unlabeled embeddings shape: (49980, 512)
# Selected indices in this iteration: [13598, 13689, 19811, 47601, 38428, 23226, 3639, 1435, 6685, 33535]
# Total labeled samples after iteration 3: 30
# Epoch 10/200: Loss = 0.4996, Test Accuracy = 42.85%
# Epoch 20/200: Loss = 0.0425, Test Accuracy = 54.58%
# Epoch 30/200: Loss = 0.0135, Test Accuracy = 51.49%
# Epoch 40/200: Loss = 0.0081, Test Accuracy = 50.05%
# Epoch 50/200: Loss = 0.0065, Test Accuracy = 50.32%
# Epoch 60/200: Loss = 0.0058, Test Accuracy = 50.81%
# Epoch 70/200: Loss = 0.0054, Test Accuracy = 51.23%
# Epoch 80/200: Loss = 0.0051, Test Accuracy = 51.37%
# Epoch 90/200: Loss = 0.0050, Test Accuracy = 51.38%
# Epoch 100/200: Loss = 0.0048, Test Accuracy = 51.46%
# Epoch 110/200: Loss = 0.0047, Test Accuracy = 51.51%
# Epoch 120/200: Loss = 0.0046, Test Accuracy = 51.52%
# Epoch 130/200: Loss = 0.0046, Test Accuracy = 51.55%
# Epoch 140/200: Loss = 0.0045, Test Accuracy = 51.58%
# Epoch 150/200: Loss = 0.0045, Test Accuracy = 51.57%
# Epoch 160/200: Loss = 0.0045, Test Accuracy = 51.58%
# Epoch 170/200: Loss = 0.0045, Test Accuracy = 51.59%
# Epoch 180/200: Loss = 0.0044, Test Accuracy = 51.59%
# Epoch 190/200: Loss = 0.0044, Test Accuracy = 51.59%
# Epoch 200/200: Loss = 0.0044, Test Accuracy = 51.59%
# Iteration 3: Cumulative Budget = 30, Test Accuracy = 51.59%
#
# Active Learning Iteration 4/6
# Current labeled samples: 30
# Current unlabeled samples: 49970
# Unlabeled embeddings shape: (49970, 512)
# Selected indices in this iteration: [26765, 36272, 32639, 34997, 45291, 48028, 9961, 17093, 35305, 16137]
# Total labeled samples after iteration 4: 40
# Epoch 10/200: Loss = 0.6781, Test Accuracy = 48.03%
# Epoch 20/200: Loss = 0.0837, Test Accuracy = 62.96%
# Epoch 30/200: Loss = 0.0251, Test Accuracy = 58.52%
# Epoch 40/200: Loss = 0.0152, Test Accuracy = 58.42%
# Epoch 50/200: Loss = 0.0120, Test Accuracy = 59.75%
# Epoch 60/200: Loss = 0.0106, Test Accuracy = 60.16%
# Epoch 70/200: Loss = 0.0099, Test Accuracy = 60.19%
# Epoch 80/200: Loss = 0.0093, Test Accuracy = 60.07%
# Epoch 90/200: Loss = 0.0089, Test Accuracy = 60.03%
# Epoch 100/200: Loss = 0.0086, Test Accuracy = 60.04%
# Epoch 110/200: Loss = 0.0084, Test Accuracy = 60.07%
# Epoch 120/200: Loss = 0.0082, Test Accuracy = 60.09%
# Epoch 130/200: Loss = 0.0081, Test Accuracy = 60.12%
# Epoch 140/200: Loss = 0.0080, Test Accuracy = 60.12%
# Epoch 150/200: Loss = 0.0079, Test Accuracy = 60.13%
# Epoch 160/200: Loss = 0.0078, Test Accuracy = 60.13%
# Epoch 170/200: Loss = 0.0078, Test Accuracy = 60.13%
# Epoch 180/200: Loss = 0.0078, Test Accuracy = 60.13%
# Epoch 190/200: Loss = 0.0078, Test Accuracy = 60.13%
# Epoch 200/200: Loss = 0.0078, Test Accuracy = 60.13%
# Iteration 4: Cumulative Budget = 40, Test Accuracy = 60.13%
#
# Active Learning Iteration 5/6
# Current labeled samples: 40
# Current unlabeled samples: 49960
# Unlabeled embeddings shape: (49960, 512)
# Selected indices in this iteration: [4389, 6256, 23323, 5747, 4580, 47582, 9387, 47089, 26867, 29562]
# Total labeled samples after iteration 5: 50
# Epoch 10/200: Loss = 0.8225, Test Accuracy = 55.83%
# Epoch 20/200: Loss = 0.1333, Test Accuracy = 65.95%
# Epoch 30/200: Loss = 0.0431, Test Accuracy = 62.88%
# Epoch 40/200: Loss = 0.0256, Test Accuracy = 63.13%
# Epoch 50/200: Loss = 0.0198, Test Accuracy = 63.71%
# Epoch 60/200: Loss = 0.0172, Test Accuracy = 63.80%
# Epoch 70/200: Loss = 0.0157, Test Accuracy = 63.74%
# Epoch 80/200: Loss = 0.0147, Test Accuracy = 63.74%
# Epoch 90/200: Loss = 0.0139, Test Accuracy = 63.80%
# Epoch 100/200: Loss = 0.0134, Test Accuracy = 63.85%
# Epoch 110/200: Loss = 0.0129, Test Accuracy = 63.83%
# Epoch 120/200: Loss = 0.0126, Test Accuracy = 63.82%
# Epoch 130/200: Loss = 0.0123, Test Accuracy = 63.82%
# Epoch 140/200: Loss = 0.0121, Test Accuracy = 63.81%
# Epoch 150/200: Loss = 0.0120, Test Accuracy = 63.81%
# Epoch 160/200: Loss = 0.0119, Test Accuracy = 63.82%
# Epoch 170/200: Loss = 0.0118, Test Accuracy = 63.83%
# Epoch 180/200: Loss = 0.0118, Test Accuracy = 63.82%
# Epoch 190/200: Loss = 0.0118, Test Accuracy = 63.82%
# Epoch 200/200: Loss = 0.0118, Test Accuracy = 63.82%
# Iteration 5: Cumulative Budget = 50, Test Accuracy = 63.82%
#
# Active Learning Iteration 6/6
# Current labeled samples: 50
# Current unlabeled samples: 49950
# Unlabeled embeddings shape: (49950, 512)
# Selected indices in this iteration: [45698, 44946, 13418, 21231, 42160, 34868, 26059, 5895, 19512, 9796]
# Total labeled samples after iteration 6: 60
# Epoch 10/200: Loss = 0.9087, Test Accuracy = 57.67%
# Epoch 20/200: Loss = 0.1819, Test Accuracy = 65.71%
# Epoch 30/200: Loss = 0.0667, Test Accuracy = 64.58%
# Epoch 40/200: Loss = 0.0395, Test Accuracy = 65.53%
# Epoch 50/200: Loss = 0.0301, Test Accuracy = 65.12%
# Epoch 60/200: Loss = 0.0256, Test Accuracy = 64.96%
# Epoch 70/200: Loss = 0.0230, Test Accuracy = 64.94%
# Epoch 80/200: Loss = 0.0213, Test Accuracy = 64.93%
# Epoch 90/200: Loss = 0.0200, Test Accuracy = 64.92%
# Epoch 100/200: Loss = 0.0191, Test Accuracy = 64.91%
# Epoch 110/200: Loss = 0.0183, Test Accuracy = 64.92%
# Epoch 120/200: Loss = 0.0178, Test Accuracy = 64.94%
# Epoch 130/200: Loss = 0.0174, Test Accuracy = 64.94%
# Epoch 140/200: Loss = 0.0170, Test Accuracy = 64.95%
# Epoch 150/200: Loss = 0.0168, Test Accuracy = 64.94%
# Epoch 160/200: Loss = 0.0167, Test Accuracy = 64.93%
# Epoch 170/200: Loss = 0.0166, Test Accuracy = 64.92%
# Epoch 180/200: Loss = 0.0165, Test Accuracy = 64.92%
# Epoch 190/200: Loss = 0.0165, Test Accuracy = 64.93%
# Epoch 200/200: Loss = 0.0165, Test Accuracy = 64.93%
# Iteration 6: Cumulative Budget = 60, Test Accuracy = 64.93%

# %%
num_runs = 10

cum_budget_typiclust_all = []
perf_typiclust_all = []
cum_budget_random_all = []
perf_random_all = []

print("Running experiments for TPCRP (TypiClust) selection:")
for run in range(num_runs):
    print(f"\nTPCRP Run {run+1}/{num_runs}")
    cum_budget, perf = run_active_learning(typiclust_selection, budget_per_iter, num_iterations, max_clusters)
    cum_budget_typiclust_all.append(cum_budget)
    perf_typiclust_all.append(perf)

print("\nRunning experiments for Random selection:")
for run in range(num_runs):
    print(f"\nRandom Run {run+1}/{num_runs}")
    cum_budget, perf = run_active_learning(random_selection, budget_per_iter, num_iterations, max_clusters)
    cum_budget_random_all.append(cum_budget)
    perf_random_all.append(perf)

cum_budget_typiclust_all = np.array(cum_budget_typiclust_all)
perf_typiclust_all = np.array(perf_typiclust_all)
cum_budget_random_all = np.array(cum_budget_random_all)
perf_random_all = np.array(perf_random_all)

# Compute mean and standard error (SE) across runs for each iteration.
mean_budget_tpcr = np.mean(cum_budget_typiclust_all, axis=0)
se_budget_tpcr = np.std(cum_budget_typiclust_all, axis=0, ddof=1) / math.sqrt(num_runs)
mean_perf_tpcr = np.mean(perf_typiclust_all, axis=0)
se_perf_tpcr = np.std(perf_typiclust_all, axis=0, ddof=1) / math.sqrt(num_runs)

mean_budget_rand = np.mean(cum_budget_random_all, axis=0)
se_budget_rand = np.std(cum_budget_random_all, axis=0, ddof=1) / math.sqrt(num_runs)
mean_perf_rand = np.mean(perf_random_all, axis=0)
se_perf_rand = np.std(perf_random_all, axis=0, ddof=1) / math.sqrt(num_runs)

# Plotting the mean test accuracy with standard error bars.
plt.figure(figsize=(10, 6))
iterations = np.arange(1, num_iterations+1)

plt.errorbar(mean_budget_tpcr, mean_perf_tpcr*100, yerr=se_perf_tpcr*100, fmt='-o', capsize=5, label='TypiClust (TPCRP)')
plt.errorbar(mean_budget_rand, mean_perf_rand*100, yerr=se_perf_rand*100, fmt='-o', capsize=5, label='Random Selection')

plt.xlabel('Cumulative Budget (number of labeled samples)')
plt.ylabel('Test Accuracy (%)')
plt.title('Active Learning Performance: TPCRP vs Random Selection')
plt.legend()
plt.grid(True)
plt.show()

# Save the results to a CSV file.
data = []
for i in range(num_iterations):
    data.append({
        'Iteration': i+1,
        'Method': 'TypiClust',
        'Cumulative_Budget': mean_budget_tpcr[i],
        'Mean_Test_Accuracy': mean_perf_tpcr[i],
        'SE_Test_Accuracy': se_perf_tpcr[i]
    })
    data.append({
        'Iteration': i+1,
        'Method': 'Random',
        'Cumulative_Budget': mean_budget_rand[i],
        'Mean_Test_Accuracy': mean_perf_rand[i],
        'SE_Test_Accuracy': se_perf_rand[i]
    })

results_df = pd.DataFrame(data)
results_csv_path = '/content/active_learning_results.csv'
results_df.to_csv(results_csv_path, index=False)
print(f"Results saved to {results_csv_path}")
# Out:
# Running experiments for TPCRP (TypiClust) selection:
#
# TPCRP Run 1/10
#
# Active Learning Iteration 1/6
# Current labeled samples: 0
# Current unlabeled samples: 50000
# Unlabeled embeddings shape: (50000, 512)
# Selected indices in this iteration: [8133, 42315, 9178, 30141, 30570, 18498, 47581, 20384, 29916, 17387]
# Total labeled samples after iteration 1: 10
# Epoch 10/200: Loss = 0.0594, Test Accuracy = 56.11%
# Epoch 20/200: Loss = 0.0013, Test Accuracy = 52.85%
# Epoch 30/200: Loss = 0.0004, Test Accuracy = 50.76%
# Epoch 40/200: Loss = 0.0002, Test Accuracy = 50.07%
# Epoch 50/200: Loss = 0.0002, Test Accuracy = 49.83%
# Epoch 60/200: Loss = 0.0002, Test Accuracy = 49.79%
# Epoch 70/200: Loss = 0.0002, Test Accuracy = 49.76%
# Epoch 80/200: Loss = 0.0002, Test Accuracy = 49.77%
# Epoch 90/200: Loss = 0.0002, Test Accuracy = 49.77%
# Epoch 100/200: Loss = 0.0002, Test Accuracy = 49.77%
# Epoch 110/200: Loss = 0.0002, Test Accuracy = 49.76%
# Epoch 120/200: Loss = 0.0002, Test Accuracy = 49.75%
# Epoch 130/200: Loss = 0.0002, Test Accuracy = 49.78%
# Epoch 140/200: Loss = 0.0002, Test Accuracy = 49.79%
# Epoch 150/200: Loss = 0.0002, Test Accuracy = 49.78%
# Epoch 160/200: Loss = 0.0002, Test Accuracy = 49.79%
# Epoch 170/200: Loss = 0.0002, Test Accuracy = 49.79%
# Epoch 180/200: Loss = 0.0002, Test Accuracy = 49.79%
# Epoch 190/200: Loss = 0.0002, Test Accuracy = 49.79%
# Epoch 200/200: Loss = 0.0002, Test Accuracy = 49.79%
# Iteration 1: Cumulative Budget = 10, Test Accuracy = 49.79%
#
# Active Learning Iteration 2/6
# Current labeled samples: 10
# Current unlabeled samples: 49990
# Unlabeled embeddings shape: (49990, 512)
# Selected indices in this iteration: [16868, 23817, 25082, 7845, 26289, 42707, 34580, 23156, 2814, 40502]
# Total labeled samples after iteration 2: 20
# Epoch 10/200: Loss = 0.2326, Test Accuracy = 55.62%
# Epoch 20/200: Loss = 0.0154, Test Accuracy = 60.19%
# Epoch 30/200: Loss = 0.0043, Test Accuracy = 60.36%
# Epoch 40/200: Loss = 0.0023, Test Accuracy = 60.67%
# Epoch 50/200: Loss = 0.0018, Test Accuracy = 60.73%
# Epoch 60/200: Loss = 0.0016, Test Accuracy = 60.67%
# Epoch 70/200: Loss = 0.0015, Test Accuracy = 60.57%
# Epoch 80/200: Loss = 0.0014, Test Accuracy = 60.45%
# Epoch 90/200: Loss = 0.0014, Test Accuracy = 60.34%
# Epoch 100/200: Loss = 0.0014, Test Accuracy = 60.24%
# Epoch 110/200: Loss = 0.0014, Test Accuracy = 60.15%
# Epoch 120/200: Loss = 0.0013, Test Accuracy = 60.10%
# Epoch 130/200: Loss = 0.0013, Test Accuracy = 60.07%
# Epoch 140/200: Loss = 0.0013, Test Accuracy = 60.00%
# Epoch 150/200: Loss = 0.0013, Test Accuracy = 59.99%
# Epoch 160/200: Loss = 0.0013, Test Accuracy = 59.96%
# Epoch 170/200: Loss = 0.0013, Test Accuracy = 59.96%
# Epoch 180/200: Loss = 0.0013, Test Accuracy = 59.95%
# Epoch 190/200: Loss = 0.0013, Test Accuracy = 59.95%
# Epoch 200/200: Loss = 0.0013, Test Accuracy = 59.95%
# Iteration 2: Cumulative Budget = 20, Test Accuracy = 59.95%
#
# Active Learning Iteration 3/6
# Current labeled samples: 20
# Current unlabeled samples: 49980
# Unlabeled embeddings shape: (49980, 512)
# Selected indices in this iteration: [23097, 45814, 23208, 10031, 37583, 28657, 17548, 42528, 2640, 2145]
# Total labeled samples after iteration 3: 30
# Epoch 10/200: Loss = 0.4929, Test Accuracy = 69.25%
# Epoch 20/200: Loss = 0.0350, Test Accuracy = 71.13%
# Epoch 30/200: Loss = 0.0108, Test Accuracy = 71.49%
# Epoch 40/200: Loss = 0.0065, Test Accuracy = 71.91%
# Epoch 50/200: Loss = 0.0051, Test Accuracy = 72.13%
# Epoch 60/200: Loss = 0.0046, Test Accuracy = 72.21%
# Epoch 70/200: Loss = 0.0043, Test Accuracy = 72.08%
# Epoch 80/200: Loss = 0.0042, Test Accuracy = 72.03%
# Epoch 90/200: Loss = 0.0041, Test Accuracy = 72.05%
# Epoch 100/200: Loss = 0.0040, Test Accuracy = 72.03%
# Epoch 110/200: Loss = 0.0039, Test Accuracy = 72.03%
# Epoch 120/200: Loss = 0.0038, Test Accuracy = 72.04%
# Epoch 130/200: Loss = 0.0038, Test Accuracy = 72.05%
# Epoch 140/200: Loss = 0.0037, Test Accuracy = 72.06%
# Epoch 150/200: Loss = 0.0037, Test Accuracy = 72.04%
# Epoch 160/200: Loss = 0.0037, Test Accuracy = 72.04%
# Epoch 170/200: Loss = 0.0037, Test Accuracy = 72.03%
# Epoch 180/200: Loss = 0.0037, Test Accuracy = 72.05%
# Epoch 190/200: Loss = 0.0037, Test Accuracy = 72.05%
# Epoch 200/200: Loss = 0.0037, Test Accuracy = 72.05%
# Iteration 3: Cumulative Budget = 30, Test Accuracy = 72.05%
#
# Active Learning Iteration 4/6
# Current labeled samples: 30
# Current unlabeled samples: 49970
# Unlabeled embeddings shape: (49970, 512)
# Selected indices in this iteration: [36070, 7998, 17258, 38400, 7293, 31677, 16457, 46787, 10257, 3285]
# Total labeled samples after iteration 4: 40
# Epoch 10/200: Loss = 0.6223, Test Accuracy = 71.93%
# Epoch 20/200: Loss = 0.0580, Test Accuracy = 75.71%
# Epoch 30/200: Loss = 0.0173, Test Accuracy = 75.88%
# Epoch 40/200: Loss = 0.0104, Test Accuracy = 75.88%
# Epoch 50/200: Loss = 0.0085, Test Accuracy = 75.69%
# Epoch 60/200: Loss = 0.0076, Test Accuracy = 75.68%
# Epoch 70/200: Loss = 0.0072, Test Accuracy = 75.64%
# Epoch 80/200: Loss = 0.0068, Test Accuracy = 75.63%
# Epoch 90/200: Loss = 0.0066, Test Accuracy = 75.69%
# Epoch 100/200: Loss = 0.0064, Test Accuracy = 75.75%
# Epoch 110/200: Loss = 0.0063, Test Accuracy = 75.76%
# Epoch 120/200: Loss = 0.0062, Test Accuracy = 75.79%
# Epoch 130/200: Loss = 0.0061, Test Accuracy = 75.79%
# Epoch 140/200: Loss = 0.0060, Test Accuracy = 75.80%
# Epoch 150/200: Loss = 0.0059, Test Accuracy = 75.80%
# Epoch 160/200: Loss = 0.0059, Test Accuracy = 75.80%
# Epoch 170/200: Loss = 0.0059, Test Accuracy = 75.80%
# Epoch 180/200: Loss = 0.0059, Test Accuracy = 75.81%
# Epoch 190/200: Loss = 0.0059, Test Accuracy = 75.81%
# Epoch 200/200: Loss = 0.0059, Test Accuracy = 75.81%
# Iteration 4: Cumulative Budget = 40, Test Accuracy = 75.81%
#
# Active Learning Iteration 5/6
# Current labeled samples: 40
# Current unlabeled samples: 49960
# Unlabeled embeddings shape: (49960, 512)
# Selected indices in this iteration: [44322, 17410, 411, 47834, 44994, 30471, 46926, 1277, 42170, 37319]
# Total labeled samples after iteration 5: 50
# Epoch 10/200: Loss = 0.7750, Test Accuracy = 73.83%
# Epoch 20/200: Loss = 0.0939, Test Accuracy = 75.88%
# Epoch 30/200: Loss = 0.0295, Test Accuracy = 75.77%
# Epoch 40/200: Loss = 0.0176, Test Accuracy = 76.35%
# Epoch 50/200: Loss = 0.0140, Test Accuracy = 76.44%
# Epoch 60/200: Loss = 0.0124, Test Accuracy = 76.49%
# Epoch 70/200: Loss = 0.0114, Test Accuracy = 76.57%
# Epoch 80/200: Loss = 0.0108, Test Accuracy = 76.59%
# Epoch 90/200: Loss = 0.0104, Test Accuracy = 76.59%
# Epoch 100/200: Loss = 0.0100, Test Accuracy = 76.62%
# Epoch 110/200: Loss = 0.0097, Test Accuracy = 76.65%
# Epoch 120/200: Loss = 0.0095, Test Accuracy = 76.64%
# Epoch 130/200: Loss = 0.0093, Test Accuracy = 76.64%
# Epoch 140/200: Loss = 0.0092, Test Accuracy = 76.66%
# Epoch 150/200: Loss = 0.0091, Test Accuracy = 76.67%
# Epoch 160/200: Loss = 0.0090, Test Accuracy = 76.67%
# Epoch 170/200: Loss = 0.0090, Test Accuracy = 76.68%
# Epoch 180/200: Loss = 0.0090, Test Accuracy = 76.68%
# Epoch 190/200: Loss = 0.0090, Test Accuracy = 76.67%
# Epoch 200/200: Loss = 0.0090, Test Accuracy = 76.67%
# Iteration 5: Cumulative Budget = 50, Test Accuracy = 76.67%
#
# Active Learning Iteration 6/6
# Current labeled samples: 50
# Current unlabeled samples: 49950
# Unlabeled embeddings shape: (49950, 512)
# Selected indices in this iteration: [30426, 34890, 41360, 43554, 27484, 8254, 36394, 29808, 11634, 44760]
# Total labeled samples after iteration 6: 60
# Epoch 10/200: Loss = 0.8303, Test Accuracy = 77.39%
# Epoch 20/200: Loss = 0.1166, Test Accuracy = 77.43%
# Epoch 30/200: Loss = 0.0374, Test Accuracy = 78.01%
# Epoch 40/200: Loss = 0.0222, Test Accuracy = 78.40%
# Epoch 50/200: Loss = 0.0173, Test Accuracy = 78.45%
# Epoch 60/200: Loss = 0.0152, Test Accuracy = 78.47%
# Epoch 70/200: Loss = 0.0139, Test Accuracy = 78.48%
# Epoch 80/200: Loss = 0.0131, Test Accuracy = 78.49%
# Epoch 90/200: Loss = 0.0125, Test Accuracy = 78.50%
# Epoch 100/200: Loss = 0.0120, Test Accuracy = 78.49%
# Epoch 110/200: Loss = 0.0116, Test Accuracy = 78.50%
# Epoch 120/200: Loss = 0.0113, Test Accuracy = 78.52%
# Epoch 130/200: Loss = 0.0111, Test Accuracy = 78.53%
# Epoch 140/200: Loss = 0.0109, Test Accuracy = 78.53%
# Epoch 150/200: Loss = 0.0108, Test Accuracy = 78.52%
# Epoch 160/200: Loss = 0.0107, Test Accuracy = 78.52%
# Epoch 170/200: Loss = 0.0107, Test Accuracy = 78.52%
# Epoch 180/200: Loss = 0.0106, Test Accuracy = 78.52%
# Epoch 190/200: Loss = 0.0106, Test Accuracy = 78.52%
# Epoch 200/200: Loss = 0.0106, Test Accuracy = 78.51%
# Iteration 6: Cumulative Budget = 60, Test Accuracy = 78.51%
#
# TPCRP Run 2/10
#
# Active Learning Iteration 1/6
# Current labeled samples: 0
# Current unlabeled samples: 50000
# Unlabeled embeddings shape: (50000, 512)
# Selected indices in this iteration: [8133, 37976, 42315, 9178, 18498, 30570, 20384, 32109, 29916, 34580]
# Total labeled samples after iteration 1: 10
# Epoch 10/200: Loss = 0.0564, Test Accuracy = 56.94%
# Epoch 20/200: Loss = 0.0016, Test Accuracy = 57.44%
# Epoch 30/200: Loss = 0.0005, Test Accuracy = 57.68%
# Epoch 40/200: Loss = 0.0003, Test Accuracy = 57.78%
# Epoch 50/200: Loss = 0.0003, Test Accuracy = 57.81%
# Epoch 60/200: Loss = 0.0002, Test Accuracy = 57.84%
# Epoch 70/200: Loss = 0.0002, Test Accuracy = 57.83%
# Epoch 80/200: Loss = 0.0002, Test Accuracy = 57.84%
# Epoch 90/200: Loss = 0.0002, Test Accuracy = 57.83%
# Epoch 100/200: Loss = 0.0002, Test Accuracy = 57.84%
# Epoch 110/200: Loss = 0.0002, Test Accuracy = 57.84%
# Epoch 120/200: Loss = 0.0002, Test Accuracy = 57.84%
# Epoch 130/200: Loss = 0.0002, Test Accuracy = 57.85%
# Epoch 140/200: Loss = 0.0002, Test Accuracy = 57.85%
# Epoch 150/200: Loss = 0.0002, Test Accuracy = 57.85%
# Epoch 160/200: Loss = 0.0002, Test Accuracy = 57.84%
# Epoch 170/200: Loss = 0.0002, Test Accuracy = 57.84%
# Epoch 180/200: Loss = 0.0002, Test Accuracy = 57.84%
# Epoch 190/200: Loss = 0.0002, Test Accuracy = 57.84%
# Epoch 200/200: Loss = 0.0002, Test Accuracy = 57.84%
# Iteration 1: Cumulative Budget = 10, Test Accuracy = 57.84%
#
# Active Learning Iteration 2/6
# Current labeled samples: 10
# Current unlabeled samples: 49990
# Unlabeled embeddings shape: (49990, 512)
# Selected indices in this iteration: [36070, 9408, 23208, 2145, 1681, 42528, 37583, 2640, 30141, 2814]
# Total labeled samples after iteration 2: 20
# Epoch 10/200: Loss = 0.2916, Test Accuracy = 51.46%
# Epoch 20/200: Loss = 0.0178, Test Accuracy = 59.87%
# Epoch 30/200: Loss = 0.0052, Test Accuracy = 57.92%
# Epoch 40/200: Loss = 0.0031, Test Accuracy = 56.95%
# Epoch 50/200: Loss = 0.0025, Test Accuracy = 56.31%
# Epoch 60/200: Loss = 0.0023, Test Accuracy = 56.10%
# Epoch 70/200: Loss = 0.0022, Test Accuracy = 55.87%
# Epoch 80/200: Loss = 0.0021, Test Accuracy = 55.67%
# Epoch 90/200: Loss = 0.0020, Test Accuracy = 55.50%
# Epoch 100/200: Loss = 0.0020, Test Accuracy = 55.48%
# Epoch 110/200: Loss = 0.0020, Test Accuracy = 55.46%
# Epoch 120/200: Loss = 0.0019, Test Accuracy = 55.39%
# Epoch 130/200: Loss = 0.0019, Test Accuracy = 55.32%
# Epoch 140/200: Loss = 0.0019, Test Accuracy = 55.30%
# Epoch 150/200: Loss = 0.0019, Test Accuracy = 55.29%
# Epoch 160/200: Loss = 0.0019, Test Accuracy = 55.27%
# Epoch 170/200: Loss = 0.0019, Test Accuracy = 55.27%
# Epoch 180/200: Loss = 0.0019, Test Accuracy = 55.26%
# Epoch 190/200: Loss = 0.0019, Test Accuracy = 55.25%
# Epoch 200/200: Loss = 0.0019, Test Accuracy = 55.25%
# Iteration 2: Cumulative Budget = 20, Test Accuracy = 55.25%
#
# Active Learning Iteration 3/6
# Current labeled samples: 20
# Current unlabeled samples: 49980
# Unlabeled embeddings shape: (49980, 512)
# Selected indices in this iteration: [25037, 17258, 23817, 28657, 31677, 26289, 45814, 17548, 46787, 30471]
# Total labeled samples after iteration 3: 30
# Epoch 10/200: Loss = 0.5041, Test Accuracy = 70.41%
# Epoch 20/200: Loss = 0.0382, Test Accuracy = 72.11%
# Epoch 30/200: Loss = 0.0114, Test Accuracy = 70.85%
# Epoch 40/200: Loss = 0.0071, Test Accuracy = 71.03%
# Epoch 50/200: Loss = 0.0058, Test Accuracy = 71.49%
# Epoch 60/200: Loss = 0.0053, Test Accuracy = 71.79%
# Epoch 70/200: Loss = 0.0050, Test Accuracy = 72.06%
# Epoch 80/200: Loss = 0.0048, Test Accuracy = 72.14%
# Epoch 90/200: Loss = 0.0047, Test Accuracy = 72.18%
# Epoch 100/200: Loss = 0.0046, Test Accuracy = 72.25%
# Epoch 110/200: Loss = 0.0045, Test Accuracy = 72.27%
# Epoch 120/200: Loss = 0.0044, Test Accuracy = 72.28%
# Epoch 130/200: Loss = 0.0044, Test Accuracy = 72.30%
# Epoch 140/200: Loss = 0.0043, Test Accuracy = 72.32%
# Epoch 150/200: Loss = 0.0043, Test Accuracy = 72.32%
# Epoch 160/200: Loss = 0.0043, Test Accuracy = 72.32%
# Epoch 170/200: Loss = 0.0042, Test Accuracy = 72.32%
# Epoch 180/200: Loss = 0.0042, Test Accuracy = 72.32%
# Epoch 190/200: Loss = 0.0042, Test Accuracy = 72.32%
# Epoch 200/200: Loss = 0.0042, Test Accuracy = 72.32%
# Iteration 3: Cumulative Budget = 30, Test Accuracy = 72.32%
#
# Active Learning Iteration 4/6
# Current labeled samples: 30
# Current unlabeled samples: 49970
# Unlabeled embeddings shape: (49970, 512)
# Selected indices in this iteration: [23097, 7293, 38400, 3585, 10257, 24536, 21073, 40502, 29808, 44760]
# Total labeled samples after iteration 4: 40
# Epoch 10/200: Loss = 0.6560, Test Accuracy = 75.92%
# Epoch 20/200: Loss = 0.0636, Test Accuracy = 76.82%
# Epoch 30/200: Loss = 0.0191, Test Accuracy = 76.90%
# Epoch 40/200: Loss = 0.0116, Test Accuracy = 76.95%
# Epoch 50/200: Loss = 0.0093, Test Accuracy = 77.05%
# Epoch 60/200: Loss = 0.0084, Test Accuracy = 77.01%
# Epoch 70/200: Loss = 0.0078, Test Accuracy = 77.03%
# Epoch 80/200: Loss = 0.0075, Test Accuracy = 77.08%
# Epoch 90/200: Loss = 0.0072, Test Accuracy = 77.06%
# Epoch 100/200: Loss = 0.0070, Test Accuracy = 77.06%
# Epoch 110/200: Loss = 0.0068, Test Accuracy = 77.08%
# Epoch 120/200: Loss = 0.0067, Test Accuracy = 77.09%
# Epoch 130/200: Loss = 0.0066, Test Accuracy = 77.08%
# Epoch 140/200: Loss = 0.0065, Test Accuracy = 77.08%
# Epoch 150/200: Loss = 0.0065, Test Accuracy = 77.08%
# Epoch 160/200: Loss = 0.0064, Test Accuracy = 77.09%
# Epoch 170/200: Loss = 0.0064, Test Accuracy = 77.09%
# Epoch 180/200: Loss = 0.0064, Test Accuracy = 77.09%
# Epoch 190/200: Loss = 0.0064, Test Accuracy = 77.09%
# Epoch 200/200: Loss = 0.0064, Test Accuracy = 77.09%
# Iteration 4: Cumulative Budget = 40, Test Accuracy = 77.09%
#
# Active Learning Iteration 5/6
# Current labeled samples: 40
# Current unlabeled samples: 49960
# Unlabeled embeddings shape: (49960, 512)
# Selected indices in this iteration: [28817, 33804, 42584, 2348, 1277, 16457, 105, 4527, 19479, 36394]
# Total labeled samples after iteration 5: 50
# Epoch 10/200: Loss = 0.7012, Test Accuracy = 77.91%
# Epoch 20/200: Loss = 0.0771, Test Accuracy = 78.23%
# Epoch 30/200: Loss = 0.0236, Test Accuracy = 78.72%
# Epoch 40/200: Loss = 0.0142, Test Accuracy = 78.89%
# Epoch 50/200: Loss = 0.0113, Test Accuracy = 78.98%
# Epoch 60/200: Loss = 0.0100, Test Accuracy = 79.02%
# Epoch 70/200: Loss = 0.0093, Test Accuracy = 79.01%
# Epoch 80/200: Loss = 0.0089, Test Accuracy = 79.05%
# Epoch 90/200: Loss = 0.0085, Test Accuracy = 79.05%
# Epoch 100/200: Loss = 0.0082, Test Accuracy = 79.04%
# Epoch 110/200: Loss = 0.0080, Test Accuracy = 79.07%
# Epoch 120/200: Loss = 0.0078, Test Accuracy = 79.08%
# Epoch 130/200: Loss = 0.0077, Test Accuracy = 79.08%
# Epoch 140/200: Loss = 0.0076, Test Accuracy = 79.07%
# Epoch 150/200: Loss = 0.0075, Test Accuracy = 79.07%
# Epoch 160/200: Loss = 0.0075, Test Accuracy = 79.08%
# Epoch 170/200: Loss = 0.0075, Test Accuracy = 79.08%
# Epoch 180/200: Loss = 0.0074, Test Accuracy = 79.08%
# Epoch 190/200: Loss = 0.0074, Test Accuracy = 79.08%
# Epoch 200/200: Loss = 0.0074, Test Accuracy = 79.08%
# Iteration 5: Cumulative Budget = 50, Test Accuracy = 79.08%
#
# Active Learning Iteration 6/6
# Current labeled samples: 50
# Current unlabeled samples: 49950
# Unlabeled embeddings shape: (49950, 512)
# Selected indices in this iteration: [2519, 411, 23981, 11230, 34254, 37319, 2588, 9523, 26190, 38926]
# Total labeled samples after iteration 6: 60
# Epoch 10/200: Loss = 0.7638, Test Accuracy = 75.87%
# Epoch 20/200: Loss = 0.1029, Test Accuracy = 77.14%
# Epoch 30/200: Loss = 0.0329, Test Accuracy = 77.67%
# Epoch 40/200: Loss = 0.0195, Test Accuracy = 78.27%
# Epoch 50/200: Loss = 0.0153, Test Accuracy = 78.38%
# Epoch 60/200: Loss = 0.0134, Test Accuracy = 78.31%
# Epoch 70/200: Loss = 0.0123, Test Accuracy = 78.47%
# Epoch 80/200: Loss = 0.0116, Test Accuracy = 78.48%
# Epoch 90/200: Loss = 0.0111, Test Accuracy = 78.41%
# Epoch 100/200: Loss = 0.0106, Test Accuracy = 78.43%
# Epoch 110/200: Loss = 0.0103, Test Accuracy = 78.44%
# Epoch 120/200: Loss = 0.0101, Test Accuracy = 78.44%
# Epoch 130/200: Loss = 0.0099, Test Accuracy = 78.44%
# Epoch 140/200: Loss = 0.0097, Test Accuracy = 78.42%
# Epoch 150/200: Loss = 0.0096, Test Accuracy = 78.44%
# Epoch 160/200: Loss = 0.0096, Test Accuracy = 78.44%
# Epoch 170/200: Loss = 0.0095, Test Accuracy = 78.44%
# Epoch 180/200: Loss = 0.0095, Test Accuracy = 78.44%
# Epoch 190/200: Loss = 0.0095, Test Accuracy = 78.44%
# Epoch 200/200: Loss = 0.0095, Test Accuracy = 78.44%
# Iteration 6: Cumulative Budget = 60, Test Accuracy = 78.44%
#
# TPCRP Run 3/10
#
# Active Learning Iteration 1/6
# Current labeled samples: 0
# Current unlabeled samples: 50000
# Unlabeled embeddings shape: (50000, 512)
# Selected indices in this iteration: [8133, 37976, 32109, 42315, 9178, 18498, 30570, 20384, 29916, 2814]
# Total labeled samples after iteration 1: 10
# Epoch 10/200: Loss = 0.0583, Test Accuracy = 53.61%
# Epoch 20/200: Loss = 0.0024, Test Accuracy = 54.19%
# Epoch 30/200: Loss = 0.0007, Test Accuracy = 54.52%
# Epoch 40/200: Loss = 0.0005, Test Accuracy = 54.56%
# Epoch 50/200: Loss = 0.0004, Test Accuracy = 54.62%
# Epoch 60/200: Loss = 0.0004, Test Accuracy = 54.63%
# Epoch 70/200: Loss = 0.0004, Test Accuracy = 54.64%
# Epoch 80/200: Loss = 0.0004, Test Accuracy = 54.66%
# Epoch 90/200: Loss = 0.0004, Test Accuracy = 54.62%
# Epoch 100/200: Loss = 0.0004, Test Accuracy = 54.61%
# Epoch 110/200: Loss = 0.0003, Test Accuracy = 54.66%
# Epoch 120/200: Loss = 0.0003, Test Accuracy = 54.63%
# Epoch 130/200: Loss = 0.0003, Test Accuracy = 54.67%
# Epoch 140/200: Loss = 0.0003, Test Accuracy = 54.65%
# Epoch 150/200: Loss = 0.0003, Test Accuracy = 54.62%
# Epoch 160/200: Loss = 0.0003, Test Accuracy = 54.61%
# Epoch 170/200: Loss = 0.0003, Test Accuracy = 54.62%
# Epoch 180/200: Loss = 0.0003, Test Accuracy = 54.61%
# Epoch 190/200: Loss = 0.0003, Test Accuracy = 54.61%
# Epoch 200/200: Loss = 0.0003, Test Accuracy = 54.61%
# Iteration 1: Cumulative Budget = 10, Test Accuracy = 54.61%
#
# Active Learning Iteration 2/6
# Current labeled samples: 10
# Current unlabeled samples: 49990
# Unlabeled embeddings shape: (49990, 512)
# Selected indices in this iteration: [23097, 30141, 28657, 23208, 9408, 45814, 37319, 1681, 26289, 34580]
# Total labeled samples after iteration 2: 20
# Epoch 10/200: Loss = 0.2486, Test Accuracy = 53.89%
# Epoch 20/200: Loss = 0.0131, Test Accuracy = 56.67%
# Epoch 30/200: Loss = 0.0043, Test Accuracy = 56.41%
# Epoch 40/200: Loss = 0.0028, Test Accuracy = 56.33%
# Epoch 50/200: Loss = 0.0024, Test Accuracy = 56.25%
# Epoch 60/200: Loss = 0.0022, Test Accuracy = 56.20%
# Epoch 70/200: Loss = 0.0021, Test Accuracy = 56.15%
# Epoch 80/200: Loss = 0.0020, Test Accuracy = 56.13%
# Epoch 90/200: Loss = 0.0020, Test Accuracy = 56.12%
# Epoch 100/200: Loss = 0.0019, Test Accuracy = 56.12%
# Epoch 110/200: Loss = 0.0019, Test Accuracy = 56.08%
# Epoch 120/200: Loss = 0.0019, Test Accuracy = 56.07%
# Epoch 130/200: Loss = 0.0019, Test Accuracy = 56.03%
# Epoch 140/200: Loss = 0.0019, Test Accuracy = 56.02%
# Epoch 150/200: Loss = 0.0018, Test Accuracy = 55.99%
# Epoch 160/200: Loss = 0.0018, Test Accuracy = 55.98%
# Epoch 170/200: Loss = 0.0018, Test Accuracy = 55.97%
# Epoch 180/200: Loss = 0.0018, Test Accuracy = 55.97%
# Epoch 190/200: Loss = 0.0018, Test Accuracy = 55.97%
# Epoch 200/200: Loss = 0.0018, Test Accuracy = 55.97%
# Iteration 2: Cumulative Budget = 20, Test Accuracy = 55.97%
#
# Active Learning Iteration 3/6
# Current labeled samples: 20
# Current unlabeled samples: 49980
# Unlabeled embeddings shape: (49980, 512)
# Selected indices in this iteration: [17258, 24708, 37583, 44994, 2640, 23817, 16868, 17548, 42707, 42528]
# Total labeled samples after iteration 3: 30
# Epoch 10/200: Loss = 0.4893, Test Accuracy = 70.57%
# Epoch 20/200: Loss = 0.0356, Test Accuracy = 72.16%
# Epoch 30/200: Loss = 0.0107, Test Accuracy = 73.21%
# Epoch 40/200: Loss = 0.0067, Test Accuracy = 72.92%
# Epoch 50/200: Loss = 0.0055, Test Accuracy = 72.59%
# Epoch 60/200: Loss = 0.0050, Test Accuracy = 72.56%
# Epoch 70/200: Loss = 0.0048, Test Accuracy = 72.59%
# Epoch 80/200: Loss = 0.0046, Test Accuracy = 72.67%
# Epoch 90/200: Loss = 0.0045, Test Accuracy = 72.64%
# Epoch 100/200: Loss = 0.0044, Test Accuracy = 72.63%
# Epoch 110/200: Loss = 0.0043, Test Accuracy = 72.62%
# Epoch 120/200: Loss = 0.0042, Test Accuracy = 72.63%
# Epoch 130/200: Loss = 0.0042, Test Accuracy = 72.64%
# Epoch 140/200: Loss = 0.0041, Test Accuracy = 72.64%
# Epoch 150/200: Loss = 0.0041, Test Accuracy = 72.64%
# Epoch 160/200: Loss = 0.0041, Test Accuracy = 72.64%
# Epoch 170/200: Loss = 0.0041, Test Accuracy = 72.64%
# Epoch 180/200: Loss = 0.0041, Test Accuracy = 72.63%
# Epoch 190/200: Loss = 0.0040, Test Accuracy = 72.63%
# Epoch 200/200: Loss = 0.0040, Test Accuracy = 72.63%
# Iteration 3: Cumulative Budget = 30, Test Accuracy = 72.63%
#
# Active Learning Iteration 4/6
# Current labeled samples: 30
# Current unlabeled samples: 49970
# Unlabeled embeddings shape: (49970, 512)
# Selected indices in this iteration: [36070, 7293, 42301, 38400, 2145, 4527, 16457, 46787, 29808, 31677]
# Total labeled samples after iteration 4: 40
# Epoch 10/200: Loss = 0.6380, Test Accuracy = 76.55%
# Epoch 20/200: Loss = 0.0605, Test Accuracy = 77.51%
# Epoch 30/200: Loss = 0.0187, Test Accuracy = 77.46%
# Epoch 40/200: Loss = 0.0115, Test Accuracy = 77.51%
# Epoch 50/200: Loss = 0.0093, Test Accuracy = 77.45%
# Epoch 60/200: Loss = 0.0084, Test Accuracy = 77.51%
# Epoch 70/200: Loss = 0.0079, Test Accuracy = 77.41%
# Epoch 80/200: Loss = 0.0075, Test Accuracy = 77.44%
# Epoch 90/200: Loss = 0.0072, Test Accuracy = 77.44%
# Epoch 100/200: Loss = 0.0070, Test Accuracy = 77.47%
# Epoch 110/200: Loss = 0.0069, Test Accuracy = 77.48%
# Epoch 120/200: Loss = 0.0067, Test Accuracy = 77.49%
# Epoch 130/200: Loss = 0.0066, Test Accuracy = 77.49%
# Epoch 140/200: Loss = 0.0065, Test Accuracy = 77.49%
# Epoch 150/200: Loss = 0.0065, Test Accuracy = 77.48%
# Epoch 160/200: Loss = 0.0064, Test Accuracy = 77.48%
# Epoch 170/200: Loss = 0.0064, Test Accuracy = 77.49%
# Epoch 180/200: Loss = 0.0064, Test Accuracy = 77.49%
# Epoch 190/200: Loss = 0.0064, Test Accuracy = 77.49%
# Epoch 200/200: Loss = 0.0064, Test Accuracy = 77.49%
# Iteration 4: Cumulative Budget = 40, Test Accuracy = 77.49%
#
# Active Learning Iteration 5/6
# Current labeled samples: 40
# Current unlabeled samples: 49960
# Unlabeled embeddings shape: (49960, 512)
# Selected indices in this iteration: [46727, 47834, 23888, 33804, 36394, 30471, 2348, 45488, 19479, 42913]
# Total labeled samples after iteration 5: 50
# Epoch 10/200: Loss = 0.7299, Test Accuracy = 77.62%
# Epoch 20/200: Loss = 0.0854, Test Accuracy = 77.66%
# Epoch 30/200: Loss = 0.0266, Test Accuracy = 78.26%
# Epoch 40/200: Loss = 0.0161, Test Accuracy = 78.46%
# Epoch 50/200: Loss = 0.0128, Test Accuracy = 78.59%
# Epoch 60/200: Loss = 0.0114, Test Accuracy = 78.73%
# Epoch 70/200: Loss = 0.0105, Test Accuracy = 78.82%
# Epoch 80/200: Loss = 0.0100, Test Accuracy = 78.82%
# Epoch 90/200: Loss = 0.0096, Test Accuracy = 78.83%
# Epoch 100/200: Loss = 0.0092, Test Accuracy = 78.84%
# Epoch 110/200: Loss = 0.0090, Test Accuracy = 78.84%
# Epoch 120/200: Loss = 0.0088, Test Accuracy = 78.84%
# Epoch 130/200: Loss = 0.0086, Test Accuracy = 78.85%
# Epoch 140/200: Loss = 0.0085, Test Accuracy = 78.85%
# Epoch 150/200: Loss = 0.0084, Test Accuracy = 78.85%
# Epoch 160/200: Loss = 0.0084, Test Accuracy = 78.86%
# Epoch 170/200: Loss = 0.0083, Test Accuracy = 78.86%
# Epoch 180/200: Loss = 0.0083, Test Accuracy = 78.84%
# Epoch 190/200: Loss = 0.0083, Test Accuracy = 78.84%
# Epoch 200/200: Loss = 0.0083, Test Accuracy = 78.84%
# Iteration 5: Cumulative Budget = 50, Test Accuracy = 78.84%
#
# Active Learning Iteration 6/6
# Current labeled samples: 50
# Current unlabeled samples: 49950
# Unlabeled embeddings shape: (49950, 512)
# Selected indices in this iteration: [37869, 23981, 23365, 1277, 16688, 2759, 8254, 7998, 45114, 9523]
# Total labeled samples after iteration 6: 60
# Epoch 10/200: Loss = 0.7896, Test Accuracy = 80.64%
# Epoch 20/200: Loss = 0.1070, Test Accuracy = 80.73%
# Epoch 30/200: Loss = 0.0348, Test Accuracy = 81.06%
# Epoch 40/200: Loss = 0.0209, Test Accuracy = 80.99%
# Epoch 50/200: Loss = 0.0164, Test Accuracy = 80.98%
# Epoch 60/200: Loss = 0.0144, Test Accuracy = 81.01%
# Epoch 70/200: Loss = 0.0133, Test Accuracy = 81.08%
# Epoch 80/200: Loss = 0.0125, Test Accuracy = 81.10%
# Epoch 90/200: Loss = 0.0119, Test Accuracy = 81.13%
# Epoch 100/200: Loss = 0.0115, Test Accuracy = 81.12%
# Epoch 110/200: Loss = 0.0111, Test Accuracy = 81.10%
# Epoch 120/200: Loss = 0.0108, Test Accuracy = 81.10%
# Epoch 130/200: Loss = 0.0106, Test Accuracy = 81.10%
# Epoch 140/200: Loss = 0.0105, Test Accuracy = 81.09%
# Epoch 150/200: Loss = 0.0103, Test Accuracy = 81.08%
# Epoch 160/200: Loss = 0.0103, Test Accuracy = 81.10%
# Epoch 170/200: Loss = 0.0102, Test Accuracy = 81.10%
# Epoch 180/200: Loss = 0.0102, Test Accuracy = 81.10%
# Epoch 190/200: Loss = 0.0102, Test Accuracy = 81.11%
# Epoch 200/200: Loss = 0.0102, Test Accuracy = 81.11%
# Iteration 6: Cumulative Budget = 60, Test Accuracy = 81.11%
#
# TPCRP Run 4/10
#
# Active Learning Iteration 1/6
# Current labeled samples: 0
# Current unlabeled samples: 50000
# Unlabeled embeddings shape: (50000, 512)
# Selected indices in this iteration: [2814, 37976, 42315, 32109, 18498, 30570, 20384, 9178, 8133, 29916]
# Total labeled samples after iteration 1: 10
# Epoch 10/200: Loss = 0.0585, Test Accuracy = 53.53%
# Epoch 20/200: Loss = 0.0024, Test Accuracy = 53.86%
# Epoch 30/200: Loss = 0.0007, Test Accuracy = 54.19%
# Epoch 40/200: Loss = 0.0005, Test Accuracy = 54.31%
# Epoch 50/200: Loss = 0.0004, Test Accuracy = 54.30%
# Epoch 60/200: Loss = 0.0004, Test Accuracy = 54.37%
# Epoch 70/200: Loss = 0.0004, Test Accuracy = 54.35%
# Epoch 80/200: Loss = 0.0004, Test Accuracy = 54.37%
# Epoch 90/200: Loss = 0.0004, Test Accuracy = 54.34%
# Epoch 100/200: Loss = 0.0003, Test Accuracy = 54.31%
# Epoch 110/200: Loss = 0.0003, Test Accuracy = 54.32%
# Epoch 120/200: Loss = 0.0003, Test Accuracy = 54.29%
# Epoch 130/200: Loss = 0.0003, Test Accuracy = 54.31%
# Epoch 140/200: Loss = 0.0003, Test Accuracy = 54.31%
# Epoch 150/200: Loss = 0.0003, Test Accuracy = 54.29%
# Epoch 160/200: Loss = 0.0003, Test Accuracy = 54.28%
# Epoch 170/200: Loss = 0.0003, Test Accuracy = 54.29%
# Epoch 180/200: Loss = 0.0003, Test Accuracy = 54.29%
# Epoch 190/200: Loss = 0.0003, Test Accuracy = 54.29%
# Epoch 200/200: Loss = 0.0003, Test Accuracy = 54.29%
# Iteration 1: Cumulative Budget = 10, Test Accuracy = 54.29%
#
# Active Learning Iteration 2/6
# Current labeled samples: 10
# Current unlabeled samples: 49990
# Unlabeled embeddings shape: (49990, 512)
# Selected indices in this iteration: [9408, 28657, 23817, 30141, 23097, 46787, 37583, 1681, 34580, 37319]
# Total labeled samples after iteration 2: 20
# Epoch 10/200: Loss = 0.2896, Test Accuracy = 57.43%
# Epoch 20/200: Loss = 0.0159, Test Accuracy = 64.94%
# Epoch 30/200: Loss = 0.0051, Test Accuracy = 64.52%
# Epoch 40/200: Loss = 0.0032, Test Accuracy = 64.01%
# Epoch 50/200: Loss = 0.0026, Test Accuracy = 63.82%
# Epoch 60/200: Loss = 0.0024, Test Accuracy = 63.67%
# Epoch 70/200: Loss = 0.0023, Test Accuracy = 63.59%
# Epoch 80/200: Loss = 0.0022, Test Accuracy = 63.59%
# Epoch 90/200: Loss = 0.0021, Test Accuracy = 63.52%
# Epoch 100/200: Loss = 0.0021, Test Accuracy = 63.47%
# Epoch 110/200: Loss = 0.0021, Test Accuracy = 63.46%
# Epoch 120/200: Loss = 0.0020, Test Accuracy = 63.37%
# Epoch 130/200: Loss = 0.0020, Test Accuracy = 63.35%
# Epoch 140/200: Loss = 0.0020, Test Accuracy = 63.36%
# Epoch 150/200: Loss = 0.0020, Test Accuracy = 63.34%
# Epoch 160/200: Loss = 0.0020, Test Accuracy = 63.34%
# Epoch 170/200: Loss = 0.0020, Test Accuracy = 63.30%
# Epoch 180/200: Loss = 0.0020, Test Accuracy = 63.30%
# Epoch 190/200: Loss = 0.0020, Test Accuracy = 63.30%
# Epoch 200/200: Loss = 0.0020, Test Accuracy = 63.30%
# Iteration 2: Cumulative Budget = 20, Test Accuracy = 63.30%
#
# Active Learning Iteration 3/6
# Current labeled samples: 20
# Current unlabeled samples: 49980
# Unlabeled embeddings shape: (49980, 512)
# Selected indices in this iteration: [12390, 16868, 26289, 10365, 17957, 31677, 2640, 42528, 20273, 30269]
# Total labeled samples after iteration 3: 30
# Epoch 10/200: Loss = 0.5029, Test Accuracy = 71.52%
# Epoch 20/200: Loss = 0.0391, Test Accuracy = 72.15%
# Epoch 30/200: Loss = 0.0119, Test Accuracy = 71.64%
# Epoch 40/200: Loss = 0.0075, Test Accuracy = 71.57%
# Epoch 50/200: Loss = 0.0062, Test Accuracy = 71.67%
# Epoch 60/200: Loss = 0.0056, Test Accuracy = 71.94%
# Epoch 70/200: Loss = 0.0053, Test Accuracy = 72.22%
# Epoch 80/200: Loss = 0.0051, Test Accuracy = 72.42%
# Epoch 90/200: Loss = 0.0049, Test Accuracy = 72.53%
# Epoch 100/200: Loss = 0.0048, Test Accuracy = 72.58%
# Epoch 110/200: Loss = 0.0047, Test Accuracy = 72.64%
# Epoch 120/200: Loss = 0.0046, Test Accuracy = 72.68%
# Epoch 130/200: Loss = 0.0046, Test Accuracy = 72.70%
# Epoch 140/200: Loss = 0.0045, Test Accuracy = 72.71%
# Epoch 150/200: Loss = 0.0045, Test Accuracy = 72.73%
# Epoch 160/200: Loss = 0.0045, Test Accuracy = 72.73%
# Epoch 170/200: Loss = 0.0045, Test Accuracy = 72.73%
# Epoch 180/200: Loss = 0.0045, Test Accuracy = 72.73%
# Epoch 190/200: Loss = 0.0044, Test Accuracy = 72.73%
# Epoch 200/200: Loss = 0.0044, Test Accuracy = 72.73%
# Iteration 3: Cumulative Budget = 30, Test Accuracy = 72.73%
#
# Active Learning Iteration 4/6
# Current labeled samples: 30
# Current unlabeled samples: 49970
# Unlabeled embeddings shape: (49970, 512)
# Selected indices in this iteration: [17258, 36070, 42301, 7293, 38400, 31301, 27484, 23888, 33804, 30471]
# Total labeled samples after iteration 4: 40
# Epoch 10/200: Loss = 0.6211, Test Accuracy = 72.25%
# Epoch 20/200: Loss = 0.0630, Test Accuracy = 75.66%
# Epoch 30/200: Loss = 0.0189, Test Accuracy = 75.32%
# Epoch 40/200: Loss = 0.0114, Test Accuracy = 75.47%
# Epoch 50/200: Loss = 0.0092, Test Accuracy = 75.68%
# Epoch 60/200: Loss = 0.0083, Test Accuracy = 75.72%
# Epoch 70/200: Loss = 0.0077, Test Accuracy = 75.73%
# Epoch 80/200: Loss = 0.0073, Test Accuracy = 75.70%
# Epoch 90/200: Loss = 0.0071, Test Accuracy = 75.73%
# Epoch 100/200: Loss = 0.0069, Test Accuracy = 75.78%
# Epoch 110/200: Loss = 0.0067, Test Accuracy = 75.76%
# Epoch 120/200: Loss = 0.0066, Test Accuracy = 75.77%
# Epoch 130/200: Loss = 0.0065, Test Accuracy = 75.77%
# Epoch 140/200: Loss = 0.0064, Test Accuracy = 75.78%
# Epoch 150/200: Loss = 0.0063, Test Accuracy = 75.79%
# Epoch 160/200: Loss = 0.0063, Test Accuracy = 75.80%
# Epoch 170/200: Loss = 0.0063, Test Accuracy = 75.79%
# Epoch 180/200: Loss = 0.0062, Test Accuracy = 75.79%
# Epoch 190/200: Loss = 0.0062, Test Accuracy = 75.79%
# Epoch 200/200: Loss = 0.0062, Test Accuracy = 75.79%
# Iteration 4: Cumulative Budget = 40, Test Accuracy = 75.79%
#
# Active Learning Iteration 5/6
# Current labeled samples: 40
# Current unlabeled samples: 49960
# Unlabeled embeddings shape: (49960, 512)
# Selected indices in this iteration: [30426, 1209, 47136, 47834, 16457, 36394, 35586, 19479, 7845, 44760]
# Total labeled samples after iteration 5: 50
# Epoch 10/200: Loss = 0.7419, Test Accuracy = 72.56%
# Epoch 20/200: Loss = 0.0936, Test Accuracy = 75.99%
# Epoch 30/200: Loss = 0.0291, Test Accuracy = 76.42%
# Epoch 40/200: Loss = 0.0173, Test Accuracy = 77.66%
# Epoch 50/200: Loss = 0.0136, Test Accuracy = 78.05%
# Epoch 60/200: Loss = 0.0120, Test Accuracy = 78.12%
# Epoch 70/200: Loss = 0.0111, Test Accuracy = 77.97%
# Epoch 80/200: Loss = 0.0105, Test Accuracy = 77.85%
# Epoch 90/200: Loss = 0.0100, Test Accuracy = 77.88%
# Epoch 100/200: Loss = 0.0097, Test Accuracy = 77.85%
# Epoch 110/200: Loss = 0.0094, Test Accuracy = 77.84%
# Epoch 120/200: Loss = 0.0092, Test Accuracy = 77.85%
# Epoch 130/200: Loss = 0.0090, Test Accuracy = 77.86%
# Epoch 140/200: Loss = 0.0089, Test Accuracy = 77.86%
# Epoch 150/200: Loss = 0.0088, Test Accuracy = 77.87%
# Epoch 160/200: Loss = 0.0087, Test Accuracy = 77.88%
# Epoch 170/200: Loss = 0.0087, Test Accuracy = 77.88%
# Epoch 180/200: Loss = 0.0087, Test Accuracy = 77.88%
# Epoch 190/200: Loss = 0.0087, Test Accuracy = 77.88%
# Epoch 200/200: Loss = 0.0087, Test Accuracy = 77.88%
# Iteration 5: Cumulative Budget = 50, Test Accuracy = 77.88%
#
# Active Learning Iteration 6/6
# Current labeled samples: 50
# Current unlabeled samples: 49950
# Unlabeled embeddings shape: (49950, 512)
# Selected indices in this iteration: [41360, 411, 8432, 37580, 40078, 30921, 3858, 45927, 40502, 2145]
# Total labeled samples after iteration 6: 60
# Epoch 10/200: Loss = 0.8430, Test Accuracy = 77.47%
# Epoch 20/200: Loss = 0.1317, Test Accuracy = 77.80%
# Epoch 30/200: Loss = 0.0437, Test Accuracy = 79.58%
# Epoch 40/200: Loss = 0.0261, Test Accuracy = 79.60%
# Epoch 50/200: Loss = 0.0202, Test Accuracy = 79.43%
# Epoch 60/200: Loss = 0.0176, Test Accuracy = 79.53%
# Epoch 70/200: Loss = 0.0160, Test Accuracy = 79.58%
# Epoch 80/200: Loss = 0.0150, Test Accuracy = 79.62%
# Epoch 90/200: Loss = 0.0142, Test Accuracy = 79.60%
# Epoch 100/200: Loss = 0.0136, Test Accuracy = 79.58%
# Epoch 110/200: Loss = 0.0132, Test Accuracy = 79.57%
# Epoch 120/200: Loss = 0.0128, Test Accuracy = 79.60%
# Epoch 130/200: Loss = 0.0126, Test Accuracy = 79.62%
# Epoch 140/200: Loss = 0.0124, Test Accuracy = 79.64%
# Epoch 150/200: Loss = 0.0122, Test Accuracy = 79.64%
# Epoch 160/200: Loss = 0.0121, Test Accuracy = 79.67%
# Epoch 170/200: Loss = 0.0121, Test Accuracy = 79.67%
# Epoch 180/200: Loss = 0.0120, Test Accuracy = 79.67%
# Epoch 190/200: Loss = 0.0120, Test Accuracy = 79.67%
# Epoch 200/200: Loss = 0.0120, Test Accuracy = 79.67%
# Iteration 6: Cumulative Budget = 60, Test Accuracy = 79.67%
#
# TPCRP Run 5/10
#
# Active Learning Iteration 1/6
# Current labeled samples: 0
# Current unlabeled samples: 50000
# Unlabeled embeddings shape: (50000, 512)
# Selected indices in this iteration: [8133, 42315, 9178, 30141, 30570, 18498, 47581, 20384, 29916, 25082]
# Total labeled samples after iteration 1: 10
# Epoch 10/200: Loss = 0.0587, Test Accuracy = 56.14%
# Epoch 20/200: Loss = 0.0013, Test Accuracy = 54.78%
# Epoch 30/200: Loss = 0.0004, Test Accuracy = 53.58%
# Epoch 40/200: Loss = 0.0002, Test Accuracy = 52.94%
# Epoch 50/200: Loss = 0.0002, Test Accuracy = 52.73%
# Epoch 60/200: Loss = 0.0002, Test Accuracy = 52.66%
# Epoch 70/200: Loss = 0.0002, Test Accuracy = 52.64%
# Epoch 80/200: Loss = 0.0002, Test Accuracy = 52.64%
# Epoch 90/200: Loss = 0.0002, Test Accuracy = 52.66%
# Epoch 100/200: Loss = 0.0002, Test Accuracy = 52.66%
# Epoch 110/200: Loss = 0.0002, Test Accuracy = 52.68%
# Epoch 120/200: Loss = 0.0002, Test Accuracy = 52.63%
# Epoch 130/200: Loss = 0.0002, Test Accuracy = 52.62%
# Epoch 140/200: Loss = 0.0002, Test Accuracy = 52.61%
# Epoch 150/200: Loss = 0.0002, Test Accuracy = 52.61%
# Epoch 160/200: Loss = 0.0002, Test Accuracy = 52.61%
# Epoch 170/200: Loss = 0.0002, Test Accuracy = 52.61%
# Epoch 180/200: Loss = 0.0002, Test Accuracy = 52.61%
# Epoch 190/200: Loss = 0.0002, Test Accuracy = 52.61%
# Epoch 200/200: Loss = 0.0002, Test Accuracy = 52.61%
# Iteration 1: Cumulative Budget = 10, Test Accuracy = 52.61%
#
# Active Learning Iteration 2/6
# Current labeled samples: 10
# Current unlabeled samples: 49990
# Unlabeled embeddings shape: (49990, 512)
# Selected indices in this iteration: [19459, 16868, 23817, 22354, 46787, 37583, 42528, 34580, 2814, 9408]
# Total labeled samples after iteration 2: 20
# Epoch 10/200: Loss = 0.2707, Test Accuracy = 55.94%
# Epoch 20/200: Loss = 0.0148, Test Accuracy = 66.44%
# Epoch 30/200: Loss = 0.0046, Test Accuracy = 66.16%
# Epoch 40/200: Loss = 0.0028, Test Accuracy = 65.94%
# Epoch 50/200: Loss = 0.0022, Test Accuracy = 65.73%
# Epoch 60/200: Loss = 0.0020, Test Accuracy = 65.42%
# Epoch 70/200: Loss = 0.0019, Test Accuracy = 65.26%
# Epoch 80/200: Loss = 0.0018, Test Accuracy = 65.20%
# Epoch 90/200: Loss = 0.0018, Test Accuracy = 65.00%
# Epoch 100/200: Loss = 0.0017, Test Accuracy = 64.91%
# Epoch 110/200: Loss = 0.0017, Test Accuracy = 64.80%
# Epoch 120/200: Loss = 0.0017, Test Accuracy = 64.79%
# Epoch 130/200: Loss = 0.0017, Test Accuracy = 64.81%
# Epoch 140/200: Loss = 0.0016, Test Accuracy = 64.74%
# Epoch 150/200: Loss = 0.0016, Test Accuracy = 64.69%
# Epoch 160/200: Loss = 0.0016, Test Accuracy = 64.70%
# Epoch 170/200: Loss = 0.0016, Test Accuracy = 64.70%
# Epoch 180/200: Loss = 0.0016, Test Accuracy = 64.71%
# Epoch 190/200: Loss = 0.0016, Test Accuracy = 64.71%
# Epoch 200/200: Loss = 0.0016, Test Accuracy = 64.71%
# Iteration 2: Cumulative Budget = 20, Test Accuracy = 64.71%
#
# Active Learning Iteration 3/6
# Current labeled samples: 20
# Current unlabeled samples: 49980
# Unlabeled embeddings shape: (49980, 512)
# Selected indices in this iteration: [44760, 17258, 34833, 29601, 28657, 23097, 26289, 17548, 42707, 28692]
# Total labeled samples after iteration 3: 30
# Epoch 10/200: Loss = 0.4714, Test Accuracy = 74.82%
# Epoch 20/200: Loss = 0.0318, Test Accuracy = 75.86%
# Epoch 30/200: Loss = 0.0093, Test Accuracy = 75.47%
# Epoch 40/200: Loss = 0.0059, Test Accuracy = 75.38%
# Epoch 50/200: Loss = 0.0048, Test Accuracy = 75.39%
# Epoch 60/200: Loss = 0.0044, Test Accuracy = 75.50%
# Epoch 70/200: Loss = 0.0042, Test Accuracy = 75.54%
# Epoch 80/200: Loss = 0.0041, Test Accuracy = 75.60%
# Epoch 90/200: Loss = 0.0039, Test Accuracy = 75.61%
# Epoch 100/200: Loss = 0.0039, Test Accuracy = 75.59%
# Epoch 110/200: Loss = 0.0038, Test Accuracy = 75.59%
# Epoch 120/200: Loss = 0.0037, Test Accuracy = 75.59%
# Epoch 130/200: Loss = 0.0037, Test Accuracy = 75.59%
# Epoch 140/200: Loss = 0.0037, Test Accuracy = 75.61%
# Epoch 150/200: Loss = 0.0036, Test Accuracy = 75.61%
# Epoch 160/200: Loss = 0.0036, Test Accuracy = 75.62%
# Epoch 170/200: Loss = 0.0036, Test Accuracy = 75.62%
# Epoch 180/200: Loss = 0.0036, Test Accuracy = 75.64%
# Epoch 190/200: Loss = 0.0036, Test Accuracy = 75.65%
# Epoch 200/200: Loss = 0.0036, Test Accuracy = 75.65%
# Iteration 3: Cumulative Budget = 30, Test Accuracy = 75.65%
#
# Active Learning Iteration 4/6
# Current labeled samples: 30
# Current unlabeled samples: 49970
# Unlabeled embeddings shape: (49970, 512)
# Selected indices in this iteration: [42271, 7293, 25037, 1626, 8596, 4527, 23888, 16457, 31677, 30269]
# Total labeled samples after iteration 4: 40
# Epoch 10/200: Loss = 0.5521, Test Accuracy = 74.28%
# Epoch 20/200: Loss = 0.0483, Test Accuracy = 77.73%
# Epoch 30/200: Loss = 0.0139, Test Accuracy = 77.49%
# Epoch 40/200: Loss = 0.0086, Test Accuracy = 77.24%
# Epoch 50/200: Loss = 0.0070, Test Accuracy = 77.21%
# Epoch 60/200: Loss = 0.0063, Test Accuracy = 77.22%
# Epoch 70/200: Loss = 0.0059, Test Accuracy = 77.23%
# Epoch 80/200: Loss = 0.0057, Test Accuracy = 77.27%
# Epoch 90/200: Loss = 0.0055, Test Accuracy = 77.31%
# Epoch 100/200: Loss = 0.0054, Test Accuracy = 77.33%
# Epoch 110/200: Loss = 0.0052, Test Accuracy = 77.33%
# Epoch 120/200: Loss = 0.0051, Test Accuracy = 77.35%
# Epoch 130/200: Loss = 0.0051, Test Accuracy = 77.36%
# Epoch 140/200: Loss = 0.0050, Test Accuracy = 77.35%
# Epoch 150/200: Loss = 0.0050, Test Accuracy = 77.36%
# Epoch 160/200: Loss = 0.0050, Test Accuracy = 77.37%
# Epoch 170/200: Loss = 0.0049, Test Accuracy = 77.38%
# Epoch 180/200: Loss = 0.0049, Test Accuracy = 77.38%
# Epoch 190/200: Loss = 0.0049, Test Accuracy = 77.38%
# Epoch 200/200: Loss = 0.0049, Test Accuracy = 77.38%
# Iteration 4: Cumulative Budget = 40, Test Accuracy = 77.38%
#
# Active Learning Iteration 5/6
# Current labeled samples: 40
# Current unlabeled samples: 49960
# Unlabeled embeddings shape: (49960, 512)
# Selected indices in this iteration: [12375, 33804, 47834, 44994, 37319, 30471, 17957, 35586, 10257, 38985]
# Total labeled samples after iteration 5: 50
# Epoch 10/200: Loss = 0.6615, Test Accuracy = 74.87%
# Epoch 20/200: Loss = 0.0746, Test Accuracy = 78.97%
# Epoch 30/200: Loss = 0.0218, Test Accuracy = 78.38%
# Epoch 40/200: Loss = 0.0131, Test Accuracy = 78.06%
# Epoch 50/200: Loss = 0.0105, Test Accuracy = 78.15%
# Epoch 60/200: Loss = 0.0093, Test Accuracy = 78.25%
# Epoch 70/200: Loss = 0.0087, Test Accuracy = 78.43%
# Epoch 80/200: Loss = 0.0083, Test Accuracy = 78.49%
# Epoch 90/200: Loss = 0.0079, Test Accuracy = 78.54%
# Epoch 100/200: Loss = 0.0077, Test Accuracy = 78.56%
# Epoch 110/200: Loss = 0.0075, Test Accuracy = 78.57%
# Epoch 120/200: Loss = 0.0073, Test Accuracy = 78.57%
# Epoch 130/200: Loss = 0.0072, Test Accuracy = 78.56%
# Epoch 140/200: Loss = 0.0071, Test Accuracy = 78.56%
# Epoch 150/200: Loss = 0.0070, Test Accuracy = 78.58%
# Epoch 160/200: Loss = 0.0070, Test Accuracy = 78.58%
# Epoch 170/200: Loss = 0.0070, Test Accuracy = 78.58%
# Epoch 180/200: Loss = 0.0069, Test Accuracy = 78.58%
# Epoch 190/200: Loss = 0.0069, Test Accuracy = 78.58%
# Epoch 200/200: Loss = 0.0069, Test Accuracy = 78.58%
# Iteration 5: Cumulative Budget = 50, Test Accuracy = 78.58%
#
# Active Learning Iteration 6/6
# Current labeled samples: 50
# Current unlabeled samples: 49950
# Unlabeled embeddings shape: (49950, 512)
# Selected indices in this iteration: [10760, 24111, 20761, 38883, 23981, 10890, 1972, 27377, 836, 27954]
# Total labeled samples after iteration 6: 60
# Epoch 10/200: Loss = 0.7259, Test Accuracy = 74.65%
# Epoch 20/200: Loss = 0.0991, Test Accuracy = 78.68%
# Epoch 30/200: Loss = 0.0307, Test Accuracy = 78.79%
# Epoch 40/200: Loss = 0.0179, Test Accuracy = 78.18%
# Epoch 50/200: Loss = 0.0140, Test Accuracy = 78.21%
# Epoch 60/200: Loss = 0.0122, Test Accuracy = 78.28%
# Epoch 70/200: Loss = 0.0112, Test Accuracy = 78.28%
# Epoch 80/200: Loss = 0.0106, Test Accuracy = 78.40%
# Epoch 90/200: Loss = 0.0101, Test Accuracy = 78.47%
# Epoch 100/200: Loss = 0.0097, Test Accuracy = 78.48%
# Epoch 110/200: Loss = 0.0094, Test Accuracy = 78.50%
# Epoch 120/200: Loss = 0.0092, Test Accuracy = 78.50%
# Epoch 130/200: Loss = 0.0090, Test Accuracy = 78.46%
# Epoch 140/200: Loss = 0.0089, Test Accuracy = 78.46%
# Epoch 150/200: Loss = 0.0088, Test Accuracy = 78.45%
# Epoch 160/200: Loss = 0.0087, Test Accuracy = 78.45%
# Epoch 170/200: Loss = 0.0087, Test Accuracy = 78.45%
# Epoch 180/200: Loss = 0.0087, Test Accuracy = 78.45%
# Epoch 190/200: Loss = 0.0087, Test Accuracy = 78.45%
# Epoch 200/200: Loss = 0.0087, Test Accuracy = 78.45%
# Iteration 6: Cumulative Budget = 60, Test Accuracy = 78.45%
#
# TPCRP Run 6/10
#
# Active Learning Iteration 1/6
# Current labeled samples: 0
# Current unlabeled samples: 50000
# Unlabeled embeddings shape: (50000, 512)
# Selected indices in this iteration: [2814, 42315, 30141, 20384, 18498, 47581, 29916, 25082, 30570, 1681]
# Total labeled samples after iteration 1: 10
# Epoch 10/200: Loss = 0.0337, Test Accuracy = 43.66%
# Epoch 20/200: Loss = 0.0027, Test Accuracy = 41.91%
# Epoch 30/200: Loss = 0.0009, Test Accuracy = 41.91%
# Epoch 40/200: Loss = 0.0006, Test Accuracy = 42.23%
# Epoch 50/200: Loss = 0.0005, Test Accuracy = 42.25%
# Epoch 60/200: Loss = 0.0004, Test Accuracy = 42.35%
# Epoch 70/200: Loss = 0.0004, Test Accuracy = 42.43%
# Epoch 80/200: Loss = 0.0004, Test Accuracy = 42.46%
# Epoch 90/200: Loss = 0.0003, Test Accuracy = 42.52%
# Epoch 100/200: Loss = 0.0003, Test Accuracy = 42.57%
# Epoch 110/200: Loss = 0.0003, Test Accuracy = 42.58%
# Epoch 120/200: Loss = 0.0003, Test Accuracy = 42.62%
# Epoch 130/200: Loss = 0.0003, Test Accuracy = 42.62%
# Epoch 140/200: Loss = 0.0003, Test Accuracy = 42.63%
# Epoch 150/200: Loss = 0.0003, Test Accuracy = 42.61%
# Epoch 160/200: Loss = 0.0003, Test Accuracy = 42.62%
# Epoch 170/200: Loss = 0.0003, Test Accuracy = 42.65%
# Epoch 180/200: Loss = 0.0003, Test Accuracy = 42.65%
# Epoch 190/200: Loss = 0.0003, Test Accuracy = 42.65%
# Epoch 200/200: Loss = 0.0003, Test Accuracy = 42.65%
# Iteration 1: Cumulative Budget = 10, Test Accuracy = 42.65%
#
# Active Learning Iteration 2/6
# Current labeled samples: 10
# Current unlabeled samples: 49990
# Unlabeled embeddings shape: (49990, 512)
# Selected indices in this iteration: [9178, 23097, 16868, 28657, 23208, 46787, 37583, 37319, 26289, 34580]
# Total labeled samples after iteration 2: 20
# Epoch 10/200: Loss = 0.2571, Test Accuracy = 52.39%
# Epoch 20/200: Loss = 0.0144, Test Accuracy = 56.91%
# Epoch 30/200: Loss = 0.0042, Test Accuracy = 55.64%
# Epoch 40/200: Loss = 0.0025, Test Accuracy = 55.24%
# Epoch 50/200: Loss = 0.0020, Test Accuracy = 55.25%
# Epoch 60/200: Loss = 0.0018, Test Accuracy = 55.26%
# Epoch 70/200: Loss = 0.0017, Test Accuracy = 55.18%
# Epoch 80/200: Loss = 0.0016, Test Accuracy = 55.15%
# Epoch 90/200: Loss = 0.0015, Test Accuracy = 55.09%
# Epoch 100/200: Loss = 0.0015, Test Accuracy = 55.05%
# Epoch 110/200: Loss = 0.0015, Test Accuracy = 55.09%
# Epoch 120/200: Loss = 0.0015, Test Accuracy = 55.09%
# Epoch 130/200: Loss = 0.0015, Test Accuracy = 55.06%
# Epoch 140/200: Loss = 0.0014, Test Accuracy = 55.09%
# Epoch 150/200: Loss = 0.0014, Test Accuracy = 55.09%
# Epoch 160/200: Loss = 0.0014, Test Accuracy = 55.08%
# Epoch 170/200: Loss = 0.0014, Test Accuracy = 55.08%
# Epoch 180/200: Loss = 0.0014, Test Accuracy = 55.07%
# Epoch 190/200: Loss = 0.0014, Test Accuracy = 55.07%
# Epoch 200/200: Loss = 0.0014, Test Accuracy = 55.07%
# Iteration 2: Cumulative Budget = 20, Test Accuracy = 55.07%
#
# Active Learning Iteration 3/6
# Current labeled samples: 20
# Current unlabeled samples: 49980
# Unlabeled embeddings shape: (49980, 512)
# Selected indices in this iteration: [23817, 45814, 42528, 17548, 2640, 42707, 2145, 8133, 29808, 40502]
# Total labeled samples after iteration 3: 30
# Epoch 10/200: Loss = 0.5154, Test Accuracy = 67.79%
# Epoch 20/200: Loss = 0.0365, Test Accuracy = 71.92%
# Epoch 30/200: Loss = 0.0111, Test Accuracy = 71.25%
# Epoch 40/200: Loss = 0.0067, Test Accuracy = 71.16%
# Epoch 50/200: Loss = 0.0054, Test Accuracy = 71.24%
# Epoch 60/200: Loss = 0.0049, Test Accuracy = 71.49%
# Epoch 70/200: Loss = 0.0046, Test Accuracy = 71.58%
# Epoch 80/200: Loss = 0.0044, Test Accuracy = 71.68%
# Epoch 90/200: Loss = 0.0043, Test Accuracy = 71.70%
# Epoch 100/200: Loss = 0.0042, Test Accuracy = 71.71%
# Epoch 110/200: Loss = 0.0041, Test Accuracy = 71.74%
# Epoch 120/200: Loss = 0.0040, Test Accuracy = 71.75%
# Epoch 130/200: Loss = 0.0040, Test Accuracy = 71.79%
# Epoch 140/200: Loss = 0.0039, Test Accuracy = 71.81%
# Epoch 150/200: Loss = 0.0039, Test Accuracy = 71.82%
# Epoch 160/200: Loss = 0.0039, Test Accuracy = 71.81%
# Epoch 170/200: Loss = 0.0039, Test Accuracy = 71.81%
# Epoch 180/200: Loss = 0.0039, Test Accuracy = 71.81%
# Epoch 190/200: Loss = 0.0039, Test Accuracy = 71.81%
# Epoch 200/200: Loss = 0.0039, Test Accuracy = 71.81%
# Iteration 3: Cumulative Budget = 30, Test Accuracy = 71.81%
#
# Active Learning Iteration 4/6
# Current labeled samples: 30
# Current unlabeled samples: 49970
# Unlabeled embeddings shape: (49970, 512)
# Selected indices in this iteration: [8596, 31677, 17258, 17387, 42923, 12375, 16688, 30269, 1277, 19479]
# Total labeled samples after iteration 4: 40
# Epoch 10/200: Loss = 0.6206, Test Accuracy = 64.17%
# Epoch 20/200: Loss = 0.0608, Test Accuracy = 74.78%
# Epoch 30/200: Loss = 0.0172, Test Accuracy = 71.91%
# Epoch 40/200: Loss = 0.0105, Test Accuracy = 72.17%
# Epoch 50/200: Loss = 0.0083, Test Accuracy = 72.75%
# Epoch 60/200: Loss = 0.0075, Test Accuracy = 73.12%
# Epoch 70/200: Loss = 0.0070, Test Accuracy = 73.29%
# Epoch 80/200: Loss = 0.0067, Test Accuracy = 73.32%
# Epoch 90/200: Loss = 0.0064, Test Accuracy = 73.32%
# Epoch 100/200: Loss = 0.0062, Test Accuracy = 73.30%
# Epoch 110/200: Loss = 0.0061, Test Accuracy = 73.29%
# Epoch 120/200: Loss = 0.0060, Test Accuracy = 73.31%
# Epoch 130/200: Loss = 0.0059, Test Accuracy = 73.33%
# Epoch 140/200: Loss = 0.0058, Test Accuracy = 73.33%
# Epoch 150/200: Loss = 0.0058, Test Accuracy = 73.32%
# Epoch 160/200: Loss = 0.0057, Test Accuracy = 73.33%
# Epoch 170/200: Loss = 0.0057, Test Accuracy = 73.33%
# Epoch 180/200: Loss = 0.0057, Test Accuracy = 73.33%
# Epoch 190/200: Loss = 0.0057, Test Accuracy = 73.33%
# Epoch 200/200: Loss = 0.0057, Test Accuracy = 73.33%
# Iteration 4: Cumulative Budget = 40, Test Accuracy = 73.33%
#
# Active Learning Iteration 5/6
# Current labeled samples: 40
# Current unlabeled samples: 49960
# Unlabeled embeddings shape: (49960, 512)
# Selected indices in this iteration: [7293, 38400, 411, 44994, 47834, 27484, 43001, 16457, 30471, 44760]
# Total labeled samples after iteration 5: 50
# Epoch 10/200: Loss = 0.7513, Test Accuracy = 76.26%
# Epoch 20/200: Loss = 0.0903, Test Accuracy = 77.53%
# Epoch 30/200: Loss = 0.0279, Test Accuracy = 77.25%
# Epoch 40/200: Loss = 0.0166, Test Accuracy = 77.41%
# ...
# Epoch 110/200: Loss = 0.0009, Test Accuracy = 34.13%
# Epoch 120/200: Loss = 0.0009, Test Accuracy = 34.12%
# Epoch 130/200: Loss = 0.0009, Test Accuracy = 34.15%
# Epoch 140/200: Loss = 0.0008, Test Accuracy = 34.14%
# Epoch 150/200: Loss = 0.0008, Test Accuracy = 34.13%
# Epoch 160/200: Loss = 0.0008, Test Accuracy = 34.13%
# Epoch 170/200: Loss = 0.0008, Test Accuracy = 34.13%
# Epoch 180/200: Loss = 0.0008, Test Accuracy = 34.13%
# Epoch 190/200: Loss = 0.0008, Test Accuracy = 34.13%
# Epoch 200/200: Loss = 0.0008, Test Accuracy = 34.13%
# Iteration 1: Cumulative Budget = 10, Test Accuracy = 34.13%
#
# Active Learning Iteration 2/6
# Current labeled samples: 10
# Current unlabeled samples: 49990
# Unlabeled embeddings shape: (49990, 512)
# Selected indices in this iteration: [39094, 32617, 39840, 13658, 13378, 5658, 28865, 47516, 48546, 30591]
# Total labeled samples after iteration 2: 20
# Epoch 10/200: Loss = 0.1778, Test Accuracy = 48.59%
# Epoch 20/200: Loss = 0.0171, Test Accuracy = 46.01%
# Epoch 30/200: Loss = 0.0063, Test Accuracy = 46.97%
# Epoch 40/200: Loss = 0.0042, Test Accuracy = 47.21%
# Epoch 50/200: Loss = 0.0035, Test Accuracy = 47.20%
# Epoch 60/200: Loss = 0.0031, Test Accuracy = 47.11%
# Epoch 70/200: Loss = 0.0029, Test Accuracy = 47.17%
# Epoch 80/200: Loss = 0.0028, Test Accuracy = 47.21%
# Epoch 90/200: Loss = 0.0027, Test Accuracy = 47.22%
# Epoch 100/200: Loss = 0.0026, Test Accuracy = 47.26%
# Epoch 110/200: Loss = 0.0026, Test Accuracy = 47.26%
# Epoch 120/200: Loss = 0.0025, Test Accuracy = 47.25%
# Epoch 130/200: Loss = 0.0025, Test Accuracy = 47.27%
# Epoch 140/200: Loss = 0.0025, Test Accuracy = 47.26%
# Epoch 150/200: Loss = 0.0024, Test Accuracy = 47.28%
# Epoch 160/200: Loss = 0.0024, Test Accuracy = 47.27%
# Epoch 170/200: Loss = 0.0024, Test Accuracy = 47.28%
# Epoch 180/200: Loss = 0.0024, Test Accuracy = 47.28%
# Epoch 190/200: Loss = 0.0024, Test Accuracy = 47.28%
# Epoch 200/200: Loss = 0.0024, Test Accuracy = 47.28%
# Iteration 2: Cumulative Budget = 20, Test Accuracy = 47.28%
#
# Active Learning Iteration 3/6
# Current labeled samples: 20
# Current unlabeled samples: 49980
# Unlabeled embeddings shape: (49980, 512)
# Selected indices in this iteration: [13210, 18480, 42148, 19808, 39289, 25010, 4302, 29620, 9636, 29834]
# Total labeled samples after iteration 3: 30
# Epoch 10/200: Loss = 0.4530, Test Accuracy = 52.33%
# Epoch 20/200: Loss = 0.0442, Test Accuracy = 57.31%
# Epoch 30/200: Loss = 0.0166, Test Accuracy = 58.60%
# Epoch 40/200: Loss = 0.0098, Test Accuracy = 58.33%
# Epoch 50/200: Loss = 0.0075, Test Accuracy = 57.85%
# Epoch 60/200: Loss = 0.0065, Test Accuracy = 57.59%
# Epoch 70/200: Loss = 0.0060, Test Accuracy = 57.25%
# Epoch 80/200: Loss = 0.0057, Test Accuracy = 57.08%
# Epoch 90/200: Loss = 0.0054, Test Accuracy = 56.97%
# Epoch 100/200: Loss = 0.0052, Test Accuracy = 56.92%
# Epoch 110/200: Loss = 0.0051, Test Accuracy = 56.86%
# Epoch 120/200: Loss = 0.0050, Test Accuracy = 56.79%
# Epoch 130/200: Loss = 0.0049, Test Accuracy = 56.74%
# Epoch 140/200: Loss = 0.0048, Test Accuracy = 56.72%
# Epoch 150/200: Loss = 0.0048, Test Accuracy = 56.73%
# Epoch 160/200: Loss = 0.0047, Test Accuracy = 56.74%
# Epoch 170/200: Loss = 0.0047, Test Accuracy = 56.75%
# Epoch 180/200: Loss = 0.0047, Test Accuracy = 56.75%
# Epoch 190/200: Loss = 0.0047, Test Accuracy = 56.75%
# Epoch 200/200: Loss = 0.0047, Test Accuracy = 56.75%
# Iteration 3: Cumulative Budget = 30, Test Accuracy = 56.75%
#
# Active Learning Iteration 4/6
# Current labeled samples: 30
# Current unlabeled samples: 49970
# Unlabeled embeddings shape: (49970, 512)
# Selected indices in this iteration: [2901, 39820, 7147, 9797, 45353, 13760, 1654, 14568, 18554, 27192]
# Total labeled samples after iteration 4: 40
# Epoch 10/200: Loss = 0.6664, Test Accuracy = 64.83%
# Epoch 20/200: Loss = 0.0882, Test Accuracy = 63.54%
# Epoch 30/200: Loss = 0.0323, Test Accuracy = 65.42%
# Epoch 40/200: Loss = 0.0193, Test Accuracy = 66.09%
# Epoch 50/200: Loss = 0.0150, Test Accuracy = 66.04%
# Epoch 60/200: Loss = 0.0130, Test Accuracy = 65.79%
# Epoch 70/200: Loss = 0.0119, Test Accuracy = 65.66%
# Epoch 80/200: Loss = 0.0112, Test Accuracy = 65.56%
# Epoch 90/200: Loss = 0.0106, Test Accuracy = 65.55%
# Epoch 100/200: Loss = 0.0102, Test Accuracy = 65.50%
# Epoch 110/200: Loss = 0.0099, Test Accuracy = 65.47%
# Epoch 120/200: Loss = 0.0096, Test Accuracy = 65.49%
# Epoch 130/200: Loss = 0.0095, Test Accuracy = 65.51%
# Epoch 140/200: Loss = 0.0093, Test Accuracy = 65.50%
# Epoch 150/200: Loss = 0.0092, Test Accuracy = 65.51%
# Epoch 160/200: Loss = 0.0091, Test Accuracy = 65.50%
# Epoch 170/200: Loss = 0.0091, Test Accuracy = 65.50%
# Epoch 180/200: Loss = 0.0091, Test Accuracy = 65.50%
# Epoch 190/200: Loss = 0.0091, Test Accuracy = 65.50%
# Epoch 200/200: Loss = 0.0091, Test Accuracy = 65.50%
# Iteration 4: Cumulative Budget = 40, Test Accuracy = 65.50%
#
# Active Learning Iteration 5/6
# Current labeled samples: 40
# Current unlabeled samples: 49960
# Unlabeled embeddings shape: (49960, 512)
# Selected indices in this iteration: [43257, 42994, 23563, 19351, 44046, 18321, 26909, 39143, 36052, 34596]
# Total labeled samples after iteration 5: 50
# Epoch 10/200: Loss = 0.7570, Test Accuracy = 62.83%
# Epoch 20/200: Loss = 0.1225, Test Accuracy = 62.15%
# Epoch 30/200: Loss = 0.0439, Test Accuracy = 65.04%
# Epoch 40/200: Loss = 0.0260, Test Accuracy = 65.05%
# Epoch 50/200: Loss = 0.0199, Test Accuracy = 64.53%
# Epoch 60/200: Loss = 0.0172, Test Accuracy = 64.11%
# Epoch 70/200: Loss = 0.0157, Test Accuracy = 63.94%
# Epoch 80/200: Loss = 0.0147, Test Accuracy = 63.95%
# Epoch 90/200: Loss = 0.0140, Test Accuracy = 63.94%
# Epoch 100/200: Loss = 0.0134, Test Accuracy = 63.93%
# Epoch 110/200: Loss = 0.0130, Test Accuracy = 63.94%
# Epoch 120/200: Loss = 0.0126, Test Accuracy = 63.98%
# Epoch 130/200: Loss = 0.0124, Test Accuracy = 63.99%
# Epoch 140/200: Loss = 0.0122, Test Accuracy = 63.99%
# Epoch 150/200: Loss = 0.0120, Test Accuracy = 63.99%
# Epoch 160/200: Loss = 0.0119, Test Accuracy = 63.98%
# Epoch 170/200: Loss = 0.0119, Test Accuracy = 63.98%
# Epoch 180/200: Loss = 0.0119, Test Accuracy = 63.99%
# Epoch 190/200: Loss = 0.0118, Test Accuracy = 63.99%
# Epoch 200/200: Loss = 0.0118, Test Accuracy = 63.99%
# Iteration 5: Cumulative Budget = 50, Test Accuracy = 63.99%
#
# Active Learning Iteration 6/6
# Current labeled samples: 50
# Current unlabeled samples: 49950
# Unlabeled embeddings shape: (49950, 512)
# Selected indices in this iteration: [28690, 40566, 23234, 10938, 12733, 16279, 45177, 49057, 17520, 3582]
# Total labeled samples after iteration 6: 60
# Epoch 10/200: Loss = 0.8249, Test Accuracy = 61.87%
# Epoch 20/200: Loss = 0.1446, Test Accuracy = 66.10%
# Epoch 30/200: Loss = 0.0516, Test Accuracy = 65.96%
# Epoch 40/200: Loss = 0.0307, Test Accuracy = 66.41%
# Epoch 50/200: Loss = 0.0237, Test Accuracy = 66.59%
# Epoch 60/200: Loss = 0.0205, Test Accuracy = 66.55%
# Epoch 70/200: Loss = 0.0187, Test Accuracy = 66.57%
# Epoch 80/200: Loss = 0.0174, Test Accuracy = 66.52%
# Epoch 90/200: Loss = 0.0165, Test Accuracy = 66.48%
# Epoch 100/200: Loss = 0.0158, Test Accuracy = 66.47%
# Epoch 110/200: Loss = 0.0152, Test Accuracy = 66.50%
# Epoch 120/200: Loss = 0.0148, Test Accuracy = 66.48%
# Epoch 130/200: Loss = 0.0145, Test Accuracy = 66.52%
# Epoch 140/200: Loss = 0.0142, Test Accuracy = 66.52%
# Epoch 150/200: Loss = 0.0140, Test Accuracy = 66.53%
# Epoch 160/200: Loss = 0.0139, Test Accuracy = 66.54%
# Epoch 170/200: Loss = 0.0139, Test Accuracy = 66.54%
# Epoch 180/200: Loss = 0.0138, Test Accuracy = 66.54%
# Epoch 190/200: Loss = 0.0138, Test Accuracy = 66.54%
# Epoch 200/200: Loss = 0.0138, Test Accuracy = 66.54%
# Iteration 6: Cumulative Budget = 60, Test Accuracy = 66.54%
#
# Random Run 10/10
#
# Active Learning Iteration 1/6
# Current labeled samples: 0
# Current unlabeled samples: 50000
# Unlabeled embeddings shape: (50000, 512)
# Selected indices in this iteration: [7982, 44880, 30640, 40193, 23788, 4522, 21309, 33916, 35164, 48648]
# Total labeled samples after iteration 1: 10
# Epoch 10/200: Loss = 0.0653, Test Accuracy = 45.34%
# Epoch 20/200: Loss = 0.0025, Test Accuracy = 44.30%
# Epoch 30/200: Loss = 0.0008, Test Accuracy = 44.03%
# Epoch 40/200: Loss = 0.0005, Test Accuracy = 43.95%
# Epoch 50/200: Loss = 0.0004, Test Accuracy = 43.81%
# Epoch 60/200: Loss = 0.0004, Test Accuracy = 43.84%
# Epoch 70/200: Loss = 0.0004, Test Accuracy = 43.89%
# Epoch 80/200: Loss = 0.0004, Test Accuracy = 43.95%
# Epoch 90/200: Loss = 0.0004, Test Accuracy = 44.02%
# Epoch 100/200: Loss = 0.0004, Test Accuracy = 44.02%
# Epoch 110/200: Loss = 0.0004, Test Accuracy = 44.01%
# Epoch 120/200: Loss = 0.0004, Test Accuracy = 44.02%
# Epoch 130/200: Loss = 0.0004, Test Accuracy = 44.02%
# Epoch 140/200: Loss = 0.0004, Test Accuracy = 44.03%
# Epoch 150/200: Loss = 0.0004, Test Accuracy = 44.05%
# Epoch 160/200: Loss = 0.0004, Test Accuracy = 44.04%
# Epoch 170/200: Loss = 0.0004, Test Accuracy = 44.05%
# Epoch 180/200: Loss = 0.0004, Test Accuracy = 44.05%
# Epoch 190/200: Loss = 0.0004, Test Accuracy = 44.05%
# Epoch 200/200: Loss = 0.0004, Test Accuracy = 44.05%
# Iteration 1: Cumulative Budget = 10, Test Accuracy = 44.05%
#
# Active Learning Iteration 2/6
# Current labeled samples: 10
# Current unlabeled samples: 49990
# Unlabeled embeddings shape: (49990, 512)
# Selected indices in this iteration: [38369, 8109, 49910, 12718, 208, 3934, 48680, 23168, 29518, 12849]
# Total labeled samples after iteration 2: 20
# Epoch 10/200: Loss = 0.2434, Test Accuracy = 47.11%
# Epoch 20/200: Loss = 0.0197, Test Accuracy = 47.96%
# Epoch 30/200: Loss = 0.0058, Test Accuracy = 48.40%
# Epoch 40/200: Loss = 0.0032, Test Accuracy = 48.18%
# Epoch 50/200: Loss = 0.0025, Test Accuracy = 48.22%
# Epoch 60/200: Loss = 0.0023, Test Accuracy = 48.22%
# Epoch 70/200: Loss = 0.0022, Test Accuracy = 48.25%
# Epoch 80/200: Loss = 0.0021, Test Accuracy = 48.19%
# Epoch 90/200: Loss = 0.0020, Test Accuracy = 48.18%
# Epoch 100/200: Loss = 0.0020, Test Accuracy = 48.14%
# Epoch 110/200: Loss = 0.0020, Test Accuracy = 48.16%
# Epoch 120/200: Loss = 0.0019, Test Accuracy = 48.15%
# Epoch 130/200: Loss = 0.0019, Test Accuracy = 48.19%
# Epoch 140/200: Loss = 0.0019, Test Accuracy = 48.22%
# Epoch 150/200: Loss = 0.0019, Test Accuracy = 48.22%
# Epoch 160/200: Loss = 0.0019, Test Accuracy = 48.24%
# Epoch 170/200: Loss = 0.0019, Test Accuracy = 48.23%
# Epoch 180/200: Loss = 0.0019, Test Accuracy = 48.22%
# Epoch 190/200: Loss = 0.0019, Test Accuracy = 48.22%
# Epoch 200/200: Loss = 0.0019, Test Accuracy = 48.22%
# Iteration 2: Cumulative Budget = 20, Test Accuracy = 48.22%
#
# Active Learning Iteration 3/6
# Current labeled samples: 20
# Current unlabeled samples: 49980
# Unlabeled embeddings shape: (49980, 512)
# Selected indices in this iteration: [25544, 23293, 41338, 17850, 18093, 1204, 19939, 19898, 40031, 24654]
# Total labeled samples after iteration 3: 30
# Epoch 10/200: Loss = 0.4308, Test Accuracy = 52.53%
# Epoch 20/200: Loss = 0.0424, Test Accuracy = 53.15%
# Epoch 30/200: Loss = 0.0139, Test Accuracy = 52.91%
# Epoch 40/200: Loss = 0.0084, Test Accuracy = 53.39%
# Epoch 50/200: Loss = 0.0068, Test Accuracy = 53.76%
# Epoch 60/200: Loss = 0.0061, Test Accuracy = 54.10%
# Epoch 70/200: Loss = 0.0057, Test Accuracy = 54.16%
# Epoch 80/200: Loss = 0.0055, Test Accuracy = 54.27%
# Epoch 90/200: Loss = 0.0053, Test Accuracy = 54.24%
# Epoch 100/200: Loss = 0.0051, Test Accuracy = 54.29%
# Epoch 110/200: Loss = 0.0050, Test Accuracy = 54.30%
# Epoch 120/200: Loss = 0.0049, Test Accuracy = 54.31%
# Epoch 130/200: Loss = 0.0048, Test Accuracy = 54.34%
# Epoch 140/200: Loss = 0.0048, Test Accuracy = 54.35%
# Epoch 150/200: Loss = 0.0047, Test Accuracy = 54.34%
# Epoch 160/200: Loss = 0.0047, Test Accuracy = 54.36%
# Epoch 170/200: Loss = 0.0047, Test Accuracy = 54.36%
# Epoch 180/200: Loss = 0.0047, Test Accuracy = 54.37%
# Epoch 190/200: Loss = 0.0047, Test Accuracy = 54.37%
# Epoch 200/200: Loss = 0.0047, Test Accuracy = 54.37%
# Iteration 3: Cumulative Budget = 30, Test Accuracy = 54.37%
#
# Active Learning Iteration 4/6
# Current labeled samples: 30
# Current unlabeled samples: 49970
# Unlabeled embeddings shape: (49970, 512)
# Selected indices in this iteration: [868, 30781, 13589, 43070, 22950, 36746, 42158, 25517, 13087, 3954]
# Total labeled samples after iteration 4: 40
# Epoch 10/200: Loss = 0.6799, Test Accuracy = 54.82%
# Epoch 20/200: Loss = 0.0907, Test Accuracy = 58.92%
# Epoch 30/200: Loss = 0.0302, Test Accuracy = 58.19%
# Epoch 40/200: Loss = 0.0176, Test Accuracy = 59.19%
# Epoch 50/200: Loss = 0.0136, Test Accuracy = 59.65%
# Epoch 60/200: Loss = 0.0119, Test Accuracy = 59.73%
# Epoch 70/200: Loss = 0.0109, Test Accuracy = 59.67%
# Epoch 80/200: Loss = 0.0103, Test Accuracy = 59.68%
# Epoch 90/200: Loss = 0.0098, Test Accuracy = 59.70%
# Epoch 100/200: Loss = 0.0095, Test Accuracy = 59.66%
# Epoch 110/200: Loss = 0.0092, Test Accuracy = 59.68%
# Epoch 120/200: Loss = 0.0090, Test Accuracy = 59.67%
# Epoch 130/200: Loss = 0.0088, Test Accuracy = 59.68%
# Epoch 140/200: Loss = 0.0087, Test Accuracy = 59.68%
# Epoch 150/200: Loss = 0.0086, Test Accuracy = 59.67%
# Epoch 160/200: Loss = 0.0085, Test Accuracy = 59.67%
# Epoch 170/200: Loss = 0.0085, Test Accuracy = 59.68%
# Epoch 180/200: Loss = 0.0084, Test Accuracy = 59.68%
# Epoch 190/200: Loss = 0.0084, Test Accuracy = 59.68%
# Epoch 200/200: Loss = 0.0084, Test Accuracy = 59.68%
# Iteration 4: Cumulative Budget = 40, Test Accuracy = 59.68%
#
# Active Learning Iteration 5/6
# Current labeled samples: 40
# Current unlabeled samples: 49960
# Unlabeled embeddings shape: (49960, 512)
# Selected indices in this iteration: [37787, 18235, 9087, 6930, 41298, 28886, 49075, 25344, 19687, 27890]
# Total labeled samples after iteration 5: 50
# Epoch 10/200: Loss = 0.7388, Test Accuracy = 56.20%
# Epoch 20/200: Loss = 0.1324, Test Accuracy = 60.14%
# Epoch 30/200: Loss = 0.0464, Test Accuracy = 59.28%
# Epoch 40/200: Loss = 0.0268, Test Accuracy = 59.68%
# Epoch 50/200: Loss = 0.0203, Test Accuracy = 59.76%
# Epoch 60/200: Loss = 0.0173, Test Accuracy = 60.08%
# Epoch 70/200: Loss = 0.0156, Test Accuracy = 60.16%
# Epoch 80/200: Loss = 0.0145, Test Accuracy = 60.17%
# Epoch 90/200: Loss = 0.0138, Test Accuracy = 60.14%
# Epoch 100/200: Loss = 0.0131, Test Accuracy = 60.13%
# Epoch 110/200: Loss = 0.0127, Test Accuracy = 60.13%
# Epoch 120/200: Loss = 0.0123, Test Accuracy = 60.15%
# Epoch 130/200: Loss = 0.0121, Test Accuracy = 60.18%
# Epoch 140/200: Loss = 0.0118, Test Accuracy = 60.19%
# Epoch 150/200: Loss = 0.0117, Test Accuracy = 60.19%
# Epoch 160/200: Loss = 0.0116, Test Accuracy = 60.19%
# Epoch 170/200: Loss = 0.0115, Test Accuracy = 60.19%
# Epoch 180/200: Loss = 0.0115, Test Accuracy = 60.20%
# Epoch 190/200: Loss = 0.0115, Test Accuracy = 60.20%
# Epoch 200/200: Loss = 0.0115, Test Accuracy = 60.20%
# Iteration 5: Cumulative Budget = 50, Test Accuracy = 60.20%
#
# Active Learning Iteration 6/6
# Current labeled samples: 50
# Current unlabeled samples: 49950
# Unlabeled embeddings shape: (49950, 512)
# Selected indices in this iteration: [7236, 19720, 49914, 10439, 7561, 21846, 26888, 35369, 1623, 19503]
# Total labeled samples after iteration 6: 60
# Epoch 10/200: Loss = 0.8218, Test Accuracy = 61.41%
# Epoch 20/200: Loss = 0.1707, Test Accuracy = 60.70%
# Epoch 30/200: Loss = 0.0610, Test Accuracy = 61.67%
# Epoch 40/200: Loss = 0.0363, Test Accuracy = 61.76%
# Epoch 50/200: Loss = 0.0276, Test Accuracy = 61.85%
# Epoch 60/200: Loss = 0.0234, Test Accuracy = 61.80%
# Epoch 70/200: Loss = 0.0211, Test Accuracy = 61.95%
# Epoch 80/200: Loss = 0.0195, Test Accuracy = 61.99%
# Epoch 90/200: Loss = 0.0183, Test Accuracy = 61.95%
# Epoch 100/200: Loss = 0.0175, Test Accuracy = 61.97%
# Epoch 110/200: Loss = 0.0168, Test Accuracy = 61.93%
# Epoch 120/200: Loss = 0.0163, Test Accuracy = 61.93%
# Epoch 130/200: Loss = 0.0159, Test Accuracy = 61.92%
# Epoch 140/200: Loss = 0.0156, Test Accuracy = 61.91%
# Epoch 150/200: Loss = 0.0154, Test Accuracy = 61.93%
# Epoch 160/200: Loss = 0.0152, Test Accuracy = 61.93%
# Epoch 170/200: Loss = 0.0152, Test Accuracy = 61.93%
# Epoch 180/200: Loss = 0.0151, Test Accuracy = 61.94%
# Epoch 190/200: Loss = 0.0151, Test Accuracy = 61.94%
# Epoch 200/200: Loss = 0.0151, Test Accuracy = 61.94%
# Iteration 6: Cumulative Budget = 60, Test Accuracy = 61.94%
# Results saved to /content/active_learning_results.csv
